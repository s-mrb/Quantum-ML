# %% [markdown]
# # Migrating from Classical Machine Learning to Quantum Machine Learning: An overview and case study on Drug Discovery
#
#
# Yash Patel , Manipal University Jaipur , yash.169105220@muj.manipal.edu
#
#
# Carlos Toxtli , West Virginia University , carlos.toxtli@mail.wvu.edu , https://www.carlostoxtli.com/#quantum

# %% [markdown]
# ## ABSTRACT

# %% [markdown]
# Recent advances in Quantum Computing have opened up new dimensions in various fields for their use. This encourages teams in different fields to explore how their existing models could be ported to a quantum approach. Getting started in this field is not a straightforward task and requires domain knowledge in quantum computing. In this work, we explore how to migrate an existing model to a quantum approach. In order to demonstrate the process, we focus on the Drug Discovery field where the capabilities of Quantum Computers can be used to the fullest. Drug discovery is the process of discovering and designing new drugs and finding their potential protein targets. Several Machine Learning (ML) approaches have been used for Drug Discovery, but Quantum Machine Learning can be used to find atypical patterns in the data which Classical Machine Learning algorithms fail to find. Current approaches for Drug discovery usually take a long time and require significative resources. Quantum Machine Learning algorithms can lead to quicker discoveries. Here we discuss some methods that are used in the Drug Discovery pipeline, mainly focusing on Drug-Target Identification, along with Machine Learning and their migration to Quantum Machine Learning equivalent approaches.

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# Drug discovery is the process where new drugs are discovered or created. Drug discovery mainly involves chemistry, pharmacology, and clinical services. Cost of Drug Development is the total cost needed from drug discovery to clinical and approval. Some costs, such as out-of-pocket expenses remain unaccounted in the total cost. Also, the time duration for drug development is usually long, generally more than ten years for a single drug, which carries a huge cost. Drug development mainly has four steps: Target Identification and Validation, Compound Screening and Lead Discovery, Preclinical Development, and Clinical Development. Drug discovery comprises of Target Identification and validation along with compound screening. Drug discovery amounts to the maximum utilization of resources. The process can involve scientists to determine germs, viruses, and bacteria that cause a specific disease or illness. The time frame can range from 3–20 years, and costs can range between several million to billions of dollars.
#
# Target Identification is the initial and most important process in the drug discovery pipeline. It concerns collecting effects of a certain drug on a particular biological entity. The biological entity which is affected by a drug is termed as a target, generally a protein sequence. Identification of suitable targets and their corresponding validations increases the chances of success during the discovery process and also allows one to foresee the effects and side effects associated with the modulation of the target.
#
# Compound screening and lead discovery comprise of HTS (high throughput screening), which is an experimentation method for screening of compounds to check for any activity against a biological target. This process over the years has become automated using certain applications that use score functions that provide ranks depending on the amount of activity.
#
# Recent advances in Artificial Intelligence (AI) has led to an increase in its applications to solve new problems. Application of artificial intelligence in drug discovery is a topic that is being explored, and a substantial amount of work has been done in the past few years. This has lead to an increase in the application of AI in many pharmaceutical companies. Due to the incorporation of AI by pharmaceutical companies, many datasets have been curated in the past few years such as DrugBank, PubChem, ZINC, ChEMBL, and many more. These datasets have compounds represented in the form of SMILES which is a popular line notation of representing chemical structures. SMILES are then converted to molecular descriptors which are numerical vectors (feature vectors) that portray certain characteristics of a compound. These are generated using various geometrical, structural, and physicochemical properties. Few libraries have been developed for forming feature vectors from SMILES. Machine Learning algorithms are then used on the extracted feature vectors.
#
# Advancements in Quantum Computing have enabled to implement certain Machine Learning techniques on Quantum Computers. Quantum Computers by IBM, DWave, Rigetti are available for developers and researchers to be used, but the use is restricted. Toolkits such as PennyLane, Strawberry Fields, qiskit can be used to develop quantum computer algorithms. These toolkits have enabled developers to implement machine learning techniques to quantum computers and find new applications for their usage.

# %% [markdown]
# ## ML TO QML TRANSITION THEORY

# %% [markdown]
# Machine Learning is the study of algorithms that use statistical models to find patterns in data without providing an explicit set of rules. Machine Learning parses through the provided data, learns from it, and tries to predict the state of any new data provided. Machine Learning algorithms improve their performance if the quantity of data is increased and the data is diversified. Hence, these algorithms are best used for huge datasets. Machine Learning approaches are broadly classified into two types: Supervised and Unsupervised Learning. For the context of the case study, we relied on Supervised Learning algorithms, mainly Support Vector Machines (SVMs) and Random Forest. It has been found and stated by many researchers that SVMs and Random Forest perform the best for target identification while using the feature-based approach.
#
# Support Vector Machine is a supervised Machine Learning algorithm that is widely used for both regression and classification tasks. SVM's plot the features in a n-dimensional space with each value being a particular coordinate in the plane. These points are separated by a hyperplane, splitting them into different classes. Random Forest uses a different approach to classification. Random forest is a collection of many Decision Trees, which are graph-like structures, a model of decisions and their possible outcomes, resource cost, and utility. Both of the algorithms are best suitable for classification and regression purposes. Various case studies and research outcomes have shown that these two methods are best suitable for Drug Target Identification studies.
#
# Deep learning algorithms have been widely used in recent years, demonstrating good results for applications in different fields of study. Deep Neural Networks are Artificial Neural Networks that have multiple hidden layers. The basic building block of a neural network is a neuron which is nothing but an activation function whose coefficients are determined during the training process. A feed-forward DNN can be considered as the most basic DNN architecture, having multiple hidden layers. These are widely used for drug target identification purposes because of their ability to predict multiple numbers of tasks in a single model. We have used a simple feed-forward DNN to compare its results with the QNN counterpart.
# Classical computers work on the phenomenon of bit manipulation based on the classical gates such as the XOR, NOT, AND etc. But the Quantum Computer use a different set of gates called quantum gates. A quantum gate is a basic quantum circuit that runs on a smaller number of qubits. Quantum gates possess the property of reversibility which the classical gates lack. This enables the quantum gates to retain information throughout the operation. It is though possible to perform classical computing using the quantum reversible gates. In a classical computer, the information is represented in the form of 0's and 1's as bits, whereas the quantum computer stores information in the form of qubits. Quantum computers leverage special phenomenon of superposition which allows a qubit to be in two states simultaneously until the value of the qubit is explicitly measured. Also, another feature that quantum gates are capable of using is of quantum entanglement. Qubits that are entangled on their way into the quantum gate remain entangled on the way out, keeping their information safely sealed throughout the transition. Quantum gates are conventionally represented in the form of unitary matrices. The number of qubits in the input and output of the gate must be equal; a gate which acts on n qubits is represented by a 2^n\times 2^n unitary matrix.
#
# Quantum Computing is the process of manipulation of qubits to process information. The ability of qubits to be in superposition principle leads to a substantial speedup in the amount of information that can be processed. Quantum Machine Learning is the domain where the principles of quantum computing are leveraged to develop algorithms that can be used to solve the typical machine learning algorithms. This can be achieved by adapting the classical algorithms to run on a quantum computer. In theory, we can call quantum machine learning as a method of quantum information processing that learns input-output relations from data provided during the training phase using a quantum function or a quantum approach to learn the data and finding patterns. There are still questions and discussions going on the efficiency of such algorithms on different types of data. There are still methods to be discovered to perfect the art of using quantum computers to solve machine learning problems. Quantum Machine Learning can also be used to analyze quantum data. Quantum Machine Learning typically requires one to encode the given classical data set into a quantum computer to make it accessible for quantum information processing. This encoded data can be processed using a quantum circuit to analyze it.
#
# Certain Quantum Machine Learning approaches have already been developed, and many still are under development. One such algorithm is the Quantum Support Vector Machines. It is available in the qiskit suite for direct implementation in python. Machine Learning represents data in a matrix format and is the basis for quantum information processing. Quantum machine learning can take two forms: where classical machine learning algorithms are transformed into their quantum counterparts; to be implemented on a quantum information processor, or taking some of the computationally expensive classical machine learning subroutines and implementing them on the quantum computer. In a Quantum Support Vector Machine algorithm, the classical data is converted to the quantum state for each training example. This is then followed by hyperplane parameter optimization.
#
# Neural Networks are a series of algorithms that try to recognize underlying relationships in a set of data that mimics the process in the human brain. Neural networks are multi-layer networks of neurons that we use to classify things, make predictions. Recent advances in Quantum Computing have lead to the implementation of neural networks using the principles of Quantum Mechanics and also to be deployed to run in a Quantum Computer. Quantum Neural Networks comprise a quantum perceptron as the basic unit in the network. A quantum perceptron must satisfy linear and non-linear properties because Quantum Computing uses a combination of linear and non-linear properties of Quantum Mechanics to function. QNN operates much like a classical ANN composed of several layers of perceptrons – an input layer, one or more hidden layers, and an output layer. Each layer is fully connected to the previous layer. Each hidden layer computes a weighted sum of the outputs of the previous layer. If this is sum above a threshold, the node goes high; otherwise, it stays low. The output layer does the same thing as the hidden layer(s), except that it also checks its accuracy against the target output of the network. The network as a whole computes a function by checking which output bit is high. There are no checks to make sure exactly one output is high.

# %% [markdown]
# ## Case Study: Drug Discovery (Drug Target Identification)

# %% [markdown]
# Drug discovery is basically the discovery of new drugs. Drug Target identification is the process of identifying an entity on which the drug compound goes and binds to, usually a protein or gene. Drug research and development starts with the identification of biomolecular targets; this is the preliminary choice, as choosing a target will result in the modulation of the disease. After the target is identified, it then validated by physiological models. Such validation is nowadays is performed using computer software where each drug that is validated is awarded a score. Though the final validation comes only after clinical tests on subjects, have been performed.
# Drug Target Identification (DTI) is both a significant step and a challenge to be solved in the Drug Discovery pipeline and has attracted the attention of researches in the past few years. Traditional methods of DTI are labor-intensive and also resources intensive; hence, the focus is now being shifted to computational methods for drug target identification. Machine Learning methods are being explored for Drug Target Identification because of the ability to learn from datasets and also find patterns in the underlying data.
#
# For the purpose of the case study, we have used the DrugBank (https://www.drugbank.ca/) dataset. Drugbank is a freely available dataset containing drug and drug target information. It compromises of detailed drug data as well as detailed target data. The latest release of the Drugbank (version 5.1.4) compromises of 13,363 drug entries including 2,606 approved small molecule drugs, 1,299 approved biotech (protein/peptide) drugs, 130 nutraceuticals, and over 6,311 experimental drugs. Additionally, 5,164 non-redundant protein (i.e. drug target/enzyme/transporter/carrier) sequences are linked to these drug entries. Each DrugCard entry contains more than 200 data fields with half of the information being devoted to drug/chemical data and the other half devoted to drug target or protein data.
#
#  Machine Learning methods for drug target identification can be classified into three types: feature-based approach, similarity-based approach, and other approaches. The input to the machine learning model in a feature-based approach is a feature vector, where each value of the feature vector represents an essential chemical or biological property of the drug or the protein. Feature vectors are generated by concatenating the molecular descriptors of the drug compound and the protein descriptors of the target sequence. This can be passed as an input to a standard machine learning model such as Support Vector Machines or Random Forest. In a similarity-based approach, a similarity matrix is generated where the (x,y)th element of the matrix is the similarity of drug x and drug y. Similarly, a target similarity matrix is generated by a protein sequence alignment. Other approaches use different information about the drug, such as the pharmacological information or the biomedical information. From these drug-protein relations are extracted. There might be cases where this information might not be the real drug-target interaction.
#
# For implementing the classical Machine Learning solution, we used the feature-based approach, as this data can also be used easily with the Quantum Machine Learning algorithms. Some of the bioinformatics libraries that we used are provided in table.
#
# ![](https://docs.google.com/drawings/d/e/2PACX-1vQLcZ5H5Ogw8iDzV7aZehcC9zJt5qPbKwITsmZ_p6SqI70HBC6r13qHXU77O8B47vjRHWpaK_Dp30Oj/pub?w=960&h=720)
#
# These libraries were then used to generate the molecular and the protein descriptors of the drug and targets, respectively. These generated molecular descriptors provide information about a certain property of the drug or protein compound. The molecular descriptors and the protein descriptors are then appended to form a feature vector. For example, the size of the molecular descriptor vector be 1xn, and the size of the protein descriptor vector be 1xm, then the feature vector will have the dimensionality of 1x(n+m). This method is applied for positive drug target pair as well as a negative drug target pair. A positive drug target pair is the one where the drug combines to a particular protein sequence. For example, we have a drug A, and it combines to 4 proteins or targets in the dataset, then we have 4 positive drug target pairs and rest of the proteins will form a negative drug target pair with drug A. Positive drug target pair is labeled as one and the negative drug target pair is labeled as zero. This collection of feature vectors is then used as the input to SVM and Random Forest machine learning methods. Also, we implemented a feed-forward DNN for the same classification task.
#
#
# The recent advances in Quantum Computing and Quantum Computing have many developers, and researchers try solving real-world problems using technology. We also had a similar kind of motivation to try out a Quantum Machine Learning algorithm in the domain of drug discovery. There are four different approaches to combine the discipline of quantum computing and machine learning shown in the figure below.
#
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Qml_approaches.tif/lossless-page1-296px-Qml_approaches.tif.png)

# %% [markdown]
# ### Methodology

# %% [markdown]
# We are using the Classical Quantum approach where the data is of classical nature and the algorithm to be used is of Quantum nature. In this type of approach, the classical data is converted to quantum data. This enables the implementation of the quantum algorithms on real-world quantum computers. Also, the ability of quantum computers to leverage the phenomenon of quantum mechanics such as superposition and entanglement made us want to try out implementing the drug target identification using machine learning on quantum computers. Also, since quantum gates have the ability to be reversible, it makes them fast to process data because the previous state of the machine is known and all of the information is retained.
#
# Hypothesis-
# After comparing the way classical and quantum computer process information, we hypothesize that machine learning on quantum computers will lead to competitive results (±10%) in comparison with the classical approaches.
#
# Limitations -
# While using the toolkits for implementing quantum computing, we encountered various problems while using the libraries. While shifting from the classical approach to the quantum approach, we had to reduce the number of features that we could select to train the algorithm. This was mainly due to the lack of quantum computing power available for commercial use. On IBM-Q experience services, we could only get a maximum of 32 qubits to be used for simulation purposes and a maximum of 16 qubits to run the algorithm on a real quantum device. In both of the QSVM and QNN approaches, the number of qubits needs to be equal to the number of features that are to be trained. Our initial feature vector used in the classical machine learning approaches for a drug-target pair was of size 1x1821, this was then to be reduced to the number of qubits that we wanted to use.
#
# To reduce the number of features, we had to select the highest-ranking features from the given feature vector. This was implemented using the Principle Component Analysis (PCA). PCA is a technique used for dimensionality reduction. Dimensionality reduction is reducing the dimensions of the feature space. Feature elimination by dimensionality reduction helps to retain the simplicity of the data and also maintains the interpretability of your variables. One drawback of PCA is that we are also eliminating any benefits that the original features would bring as compared to the reduced number of dimensions. This transformation is defined in such a way that the first principal component has the largest possible variance (that is, accounts for as much of the variability in the data as possible), and each succeeding component, in turn, has the highest variance possible under the constraint that it is orthogonal to the preceding components. The resulting vectors (each being a linear combination of the variables and containing n observations) are an uncorrelated orthogonal basis set. PCA is sensitive to the relative scaling of the original variables. Also, we had to scale the data in the range [-1 , 1]. The reduction of sale will lead to changing some important descriptor values, which in their original values would have led to the finding of different patterns of correlations.

# %% [markdown]
# ### Simulators

# %% [markdown]
# Quantum Simulators are controllable quantum systems that can be used to simulate other quantum systems. Quantum simulators can help us tackle problems of quantum computing on a classical computer using an interface where quantum data is converted to classical and vice-versa. They form a bridge between the Classical-Classical algorithms and Classical-Quantum or Quantum-Classical algorithms. This data then can be used to implement Quantum Computing algorithms on a classical computer. Many toolkits are available to implement quantum simulators such as the qiskit by IBM, Pennylane by Xanadu, and many more. Quantum Simulators behave like real-world quantum computers, but they are run on classical machines.

# %% [markdown]
# ### Results

# %% [markdown]
# In our initial hypothesis, we were expecting competitive results for the QSVM and QNN implementations when compared with their classical counterparts i.e., SVM, and DNN. But the results were not competitive at all; the QSVM and QNN did not perform even close to their classical counterparts. This might have been due to the limitations of the number of features that one can select when implementing a quantum computing approach because of the limitation of the number of qubits one can use. Quantum supremacy is still quite far away, but we can hope that once we achieve quantum supremacy, we can expect to see better results for the drug target identification using Quantum Computing algorithms.
#
# ![](https://docs.google.com/drawings/d/e/2PACX-1vTPM9zLsTxotQpA5_JcMPaWhL8GE26do4WKY377rM-rGPvLdpkRKS-NvBL_3vyTS_pGSyio7oLRit75/pub?w=792&h=373)

# %% [markdown]
# ## DISCUSSION

# %% [markdown]
# In this work, we focus on covering a type of application that promises to have impactful results through the use of quantum computing. It is important to mention that we only focus on a single subarea of drug discovery that is Drug-Target Identification and other sub-areas such as Hit search or Lead search could also have a great impact. Future work can explore the algorithm migration processes for other drug discovery techniques and also for other fields of study.
#
# We did not reject the null hypothesis of considering the quantum results as competitive. It was mainly due to the limited data that the algorithms could process due to the limited number of qubits. The implemented QSVM algorithm used each qubit to process each feature, so the number of features was limited by the device that executed it, it ranged from 5 to 32 qubits depending on the IBM Q device. The same limitation affected the neural network implementation by using the Xanadu PenyLane library over a Rigetti Forest environment with ten qubits. Fairer experimentation would be performed by using the same number of features as the classical approach, but in general, the drug discovery subareas are highly demanding in features.
#
# Although the results were not competitive, there are some lessons learned that could reduce the learning curve of future implementations. Techniques that allow the best selection and reduction of features are indispensable for this limited environments. The quantum machines available in the cloud have a system of task queuing, so executions can take a long time, not because of the processing time, but because of the ability of these devices to prepare and dispatch the queued processes. It is important to note that emulators consume large amounts of memory, which depends on the information entered. It is important to make tests with different volumes of data to prevent memory saturation.
#
# It is not yet clear what type of implementations are the most benefited from the use of quantum machine learning. Future work can perform a comparison of techniques by different areas and find which front is closest to the quantum supremacy. This can lead future research work to create a simple baseline for experimentation. This type of baselines is well known in other areas such as IRIS for machine learning, MNIST for character recognition or CIFAR for classification of objects in images.

# %% [markdown]
# ## CONCLUSIONS

# %% [markdown]
# Quantum computing is an area that promises to solve the great problems of humanity by achieving a performance far superior to today's computers. Although no cases have been demonstrated in which quantum computing exceeds the classical computing in a specific task (quantum supremacy), scientists in this area ensure that we are close. In this work, we set out to understand how these types of algorithms work and how it is possible to convert conventional to quantum algorithms. To demonstrate the process of transforming a solution, we focus on a case study that promises impactful results that is drug discovery. The subarea of drug discovery in which we focus on was Drug-Target Identification. For this type of problem, classification algorithms are required. In classical computing, these problems are usually solved with machine learning algorithms. To demonstrate how to apply machine learning algorithms for quantum machine learning, we experimented with a conventional machine learning method (Support Vector Machine) and a deep learning method (Multi-Layer Perceptron). In this paper, we show step by step the process for both the conventional and quantum solutions, from the preprocessing of information to training and evaluation. The algorithms were designed to run in variational circuits. The experiments were performed in quantum computing simulators and on quantum cloud services. The results were superior in the classic solutions as expected. The contribution of this work focuses on documenting the migration process, showing the requirements, and the limitations of current quantum systems.

# %% [markdown]
# # CODE
#
# Interactive paper

# %% [markdown]
# ## VM Setup

# %%
# %%time
# !wget -c https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# !chmod +x Anaconda3-5.1.0-Linux-x86_64.sh
# !bash ./Anaconda3-5.1.0-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.6/site-packages/')
# !conda install -y --prefix /usr/local -c rdkit python=3.6
# !conda install -y --prefix /usr/local -c pip python=3.6
# !pip3 install mordred
# !pip3 install oddt pubchempy
# !pip3 install biopython
# !conda install -y -c conda-forge rdkit
# !apt install -y  openbabel
# !pip install biopython
# !conda uninstall -y sympy
# !pip install qiskit
# !python -m pip install pennylane
# Out:
# --2020-06-03 06:03:33--  https://repo.continuum.io/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh [following]
# --2020-06-03 06:03:33--  https://repo.anaconda.com/archive/Anaconda3-5.1.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 577996269 (551M) [application/x-sh]
# Saving to: ‘Anaconda3-5.1.0-Linux-x86_64.sh’
#
# Anaconda3-5.1.0-Lin 100%[===================>] 551.22M   227MB/s    in 2.4s
#
# 2020-06-03 06:03:36 (227 MB/s) - ‘Anaconda3-5.1.0-Linux-x86_64.sh’ saved [577996269/577996269]
#
# PREFIX=/usr/local
# installing: python-3.6.4-hc3d631a_1 ...
# Python 3.6.4 :: Anaconda, Inc.
# installing: ca-certificates-2017.08.26-h1d4fec5_0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: intel-openmp-2018.0.0-hc7b2577_8 ...
# installing: libgcc-ng-7.2.0-h7cc24e2_2 ...
# installing: libgfortran-ng-7.2.0-h9f7466a_2 ...
# installing: libstdcxx-ng-7.2.0-h7a57d05_2 ...
# installing: bzip2-1.0.6-h9a117a8_4 ...
# installing: expat-2.2.5-he0dffb1_0 ...
# installing: gmp-6.1.2-h6c8ec71_1 ...
# installing: graphite2-1.3.10-hf63cedd_1 ...
# installing: icu-58.2-h9c2bf20_1 ...
# installing: jbig-2.1-hdba287a_0 ...
# installing: jpeg-9b-h024ee3a_2 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: libsodium-1.0.15-hf101ebd_0 ...
# installing: libtool-2.4.6-h544aabb_3 ...
# installing: libxcb-1.12-hcd93eb1_4 ...
# installing: lzo-2.10-h49e0be7_2 ...
# installing: mkl-2018.0.1-h19d6760_4 ...
# installing: ncurses-6.0-h9df7e31_2 ...
# installing: openssl-1.0.2n-hb7f436b_0 ...
# installing: patchelf-0.9-hf79760b_2 ...
# installing: pcre-8.41-hc27e229_1 ...
# installing: pixman-0.34.0-hceecf20_3 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: unixodbc-2.3.4-hc36303a_1 ...
# installing: xz-5.2.3-h55aa19d_2 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: glib-2.53.6-h5d9569c_2 ...
# installing: hdf5-1.10.1-h9caa474_1 ...
# installing: libedit-3.1-heed3624_0 ...
# installing: libpng-1.6.34-hb9fc6fc_0 ...
# installing: libssh2-1.8.0-h9cfc8f7_4 ...
# installing: libtiff-4.0.9-h28f6b97_0 ...
# installing: libxml2-2.9.7-h26e45fe_0 ...
# installing: mpfr-3.1.5-h11a74b3_2 ...
# installing: pandoc-1.19.2.1-hea2e7c5_1 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: zeromq-4.2.2-hbedb6e5_2 ...
# installing: dbus-1.12.2-hc3f9b76_1 ...
# installing: freetype-2.8-hab7d2ae_1 ...
# installing: gstreamer-1.12.4-hb53b477_0 ...
# installing: libcurl-7.58.0-h1ad7b7a_0 ...
# installing: libxslt-1.1.32-h1312cb7_0 ...
# installing: mpc-1.0.3-hec55b23_5 ...
# installing: sqlite-3.22.0-h1bed415_0 ...
# installing: curl-7.58.0-h84994c4_0 ...
# installing: fontconfig-2.12.4-h88586e7_1 ...
# installing: gst-plugins-base-1.12.4-h33fb286_0 ...
# installing: alabaster-0.7.10-py36h306e16b_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: attrs-17.4.0-py36_0 ...
# installing: backports-1.0-py36hfa02d7e_1 ...
# installing: beautifulsoup4-4.6.0-py36h49b8c8c_1 ...
# installing: bitarray-0.8.1-py36h14c3975_1 ...
# installing: boto-2.48.0-py36h6e4cd66_1 ...
# installing: cairo-1.14.12-h77bcde2_0 ...
# installing: certifi-2018.1.18-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: click-6.7-py36h5253387_0 ...
# installing: cloudpickle-0.5.2-py36_1 ...
# installing: colorama-0.3.9-py36h489cec4_0 ...
# installing: contextlib2-0.5.5-py36h6c84a62_0 ...
# installing: dask-core-0.16.1-py36_0 ...
# installing: decorator-4.2.1-py36_0 ...
# installing: docutils-0.14-py36hb0f60f5_0 ...
# installing: entrypoints-0.2.3-py36h1aec115_2 ...
# installing: et_xmlfile-1.0.1-py36hd6bccc3_0 ...
# installing: fastcache-1.0.2-py36h14c3975_2 ...
# installing: filelock-2.0.13-py36h646ffb5_0 ...
# installing: glob2-0.6-py36he249c77_0 ...
# installing: gmpy2-2.0.8-py36hc8893dd_2 ...
# installing: greenlet-0.4.12-py36h2d503a6_0 ...
# installing: heapdict-1.0.0-py36_2 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: imagesize-0.7.1-py36h52d8127_0 ...
# installing: ipython_genutils-0.2.0-py36hb52b0d5_0 ...
# installing: itsdangerous-0.24-py36h93cc618_1 ...
# installing: jdcal-1.3-py36h4c697fb_0 ...
# installing: lazy-object-proxy-1.3.1-py36h10fcdad_0 ...
# installing: llvmlite-0.21.0-py36ha241eea_0 ...
# installing: locket-0.2.0-py36h787c0ad_1 ...
# installing: lxml-4.1.1-py36hf71bdeb_1 ...
# installing: markupsafe-1.0-py36hd9260cd_1 ...
# installing: mccabe-0.6.1-py36h5ad9710_1 ...
# installing: mistune-0.8.3-py36_0 ...
# installing: mkl-service-1.1.2-py36h17a0993_4 ...
# installing: mpmath-1.0.0-py36hfeacd6b_2 ...
# installing: msgpack-python-0.5.1-py36h6bb024c_0 ...
# installing: multipledispatch-0.4.9-py36h41da3fb_0 ...
# installing: numpy-1.14.0-py36h3dfced4_1 ...
# installing: olefile-0.45.1-py36_0 ...
# installing: pandocfilters-1.4.2-py36ha6701b7_1 ...
# installing: parso-0.1.1-py36h35f843b_0 ...
# installing: path.py-10.5-py36h55ceabb_0 ...
# installing: pep8-1.7.1-py36_0 ...
# installing: pickleshare-0.7.4-py36h63277f8_0 ...
# installing: pkginfo-1.4.1-py36h215d178_1 ...
# installing: pluggy-0.6.0-py36hb689045_0 ...
# installing: ply-3.10-py36hed35086_0 ...
# installing: psutil-5.4.3-py36h14c3975_0 ...
# installing: ptyprocess-0.5.2-py36h69acd42_0 ...
# installing: py-1.5.2-py36h29bf505_0 ...
# installing: pycodestyle-2.3.1-py36hf609f19_0 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pycrypto-2.6.1-py36h14c3975_7 ...
# installing: pycurl-7.43.0.1-py36hb7f436b_0 ...
# installing: pyodbc-4.0.22-py36hf484d3e_0 ...
# installing: pyparsing-2.2.0-py36hee85983_1 ...
# installing: pysocks-1.6.7-py36hd97a5b1_1 ...
# installing: pytz-2017.3-py36h63b9c63_0 ...
# installing: pyyaml-3.12-py36hafb9ca4_1 ...
# installing: pyzmq-16.0.3-py36he2533c7_0 ...
# installing: qt-5.6.2-h974d657_12 ...
# installing: qtpy-1.3.1-py36h3691cc8_0 ...
# installing: rope-0.10.7-py36h147e2ec_0 ...
# installing: ruamel_yaml-0.15.35-py36h14c3975_1 ...
# installing: send2trash-1.4.2-py36_0 ...
# installing: simplegeneric-0.8.1-py36_2 ...
# installing: sip-4.18.1-py36h51ed4ed_2 ...
# installing: six-1.11.0-py36h372c433_1 ...
# installing: snowballstemmer-1.2.1-py36h6febd40_0 ...
# installing: sortedcontainers-1.5.9-py36_0 ...
# installing: sphinxcontrib-1.0-py36h6d0f590_1 ...
# installing: sqlalchemy-1.2.1-py36h14c3975_0 ...
# installing: tblib-1.3.2-py36h34cf8b6_0 ...
# installing: testpath-0.3.1-py36h8cadb63_0 ...
# installing: toolz-0.9.0-py36_0 ...
# installing: tornado-4.5.3-py36_0 ...
# installing: typing-3.6.2-py36h7da032a_0 ...
# installing: unicodecsv-0.14.1-py36ha668878_0 ...
# installing: wcwidth-0.1.7-py36hdf4376a_0 ...
# installing: webencodings-0.5.1-py36h800622e_1 ...
# installing: werkzeug-0.14.1-py36_0 ...
# installing: wrapt-1.10.11-py36h28b7045_0 ...
# installing: xlrd-1.1.0-py36h1db9f0c_1 ...
# installing: xlsxwriter-1.0.2-py36h3de1aca_0 ...
# installing: xlwt-1.3.0-py36h7b00a1f_0 ...
# installing: babel-2.5.3-py36_0 ...
# installing: backports.shutil_get_terminal_size-1.0.0-py36hfea85ff_2 ...
# installing: bottleneck-1.2.1-py36haac1ea0_0 ...
# installing: cffi-1.11.4-py36h9745a5d_0 ...
# installing: conda-verify-2.0.0-py36h98955d8_0 ...
# installing: cycler-0.10.0-py36h93f1223_0 ...
# installing: cytoolz-0.9.0-py36h14c3975_0 ...
# installing: h5py-2.7.1-py36h3585f63_0 ...
# installing: harfbuzz-1.7.4-hc5b324e_0 ...
# installing: html5lib-1.0.1-py36h2f9c1c0_0 ...
# installing: jedi-0.11.1-py36_0 ...
# installing: networkx-2.1-py36_0 ...
# installing: nltk-3.2.5-py36h7532b22_0 ...
# installing: numba-0.36.2-np114py36hc6662d5_0 ...
# installing: numexpr-2.6.4-py36hc4a3f9a_0 ...
# installing: openpyxl-2.4.10-py36_0 ...
# installing: packaging-16.8-py36ha668100_1 ...
# installing: partd-0.3.8-py36h36fd896_0 ...
# installing: pathlib2-2.3.0-py36h49efa8e_0 ...
# installing: pexpect-4.3.1-py36_0 ...
# installing: pillow-5.0.0-py36h3deb7b8_0 ...
# installing: pyqt-5.6.0-py36h0386399_5 ...
# installing: python-dateutil-2.6.1-py36h88d3b88_1 ...
# installing: pywavelets-0.5.2-py36he602eb0_0 ...
# installing: qtawesome-0.4.4-py36h609ed8c_0 ...
# installing: scipy-1.0.0-py36hbf646e7_0 ...
# installing: setuptools-38.4.0-py36_0 ...
# installing: singledispatch-3.4.0.3-py36h7a266c3_0 ...
# installing: sortedcollections-0.5.3-py36h3c761f9_0 ...
# installing: sphinxcontrib-websupport-1.0.1-py36hb5cb234_1 ...
# installing: sympy-1.1.1-py36hc6d1c1c_0 ...
# installing: terminado-0.8.1-py36_1 ...
# installing: traitlets-4.3.2-py36h674d592_0 ...
# installing: zict-0.1.3-py36h3a3bf81_0 ...
# installing: astroid-1.6.1-py36_0 ...
# installing: bleach-2.1.2-py36_0 ...
# installing: clyent-1.2.2-py36h7e57e65_1 ...
# installing: cryptography-2.1.4-py36hd09be54_0 ...
# installing: cython-0.27.3-py36h1860423_0 ...
# installing: datashape-0.5.4-py36h3ad6b5c_0 ...
# installing: distributed-1.20.2-py36_0 ...
# installing: get_terminal_size-1.0.0-haa9412d_0 ...
# installing: gevent-1.2.2-py36h2fe25dc_0 ...
# installing: imageio-2.2.0-py36he555465_0 ...
# installing: isort-4.2.15-py36had401c0_0 ...
# installing: jinja2-2.10-py36ha16c418_0 ...
# installing: jsonschema-2.6.0-py36h006f8b5_0 ...
# installing: jupyter_core-4.4.0-py36h7c827e3_0 ...
# installing: matplotlib-2.1.2-py36h0e671d2_0 ...
# installing: navigator-updater-0.1.0-py36h14770f7_0 ...
# installing: nose-1.3.7-py36hcdf7029_2 ...
# installing: pandas-0.22.0-py36hf484d3e_0 ...
# installing: pango-1.41.0-hd475d92_0 ...
# installing: patsy-0.5.0-py36_0 ...
# installing: pyflakes-1.6.0-py36h7bd6a15_0 ...
# installing: pygments-2.2.0-py36h0d3125c_0 ...
# installing: pytables-3.4.2-py36h3b5282a_2 ...
# installing: pytest-3.3.2-py36_0 ...
# installing: scikit-learn-0.19.1-py36h7aa7ec6_0 ...
# installing: wheel-0.30.0-py36hfd4bba0_1 ...
# installing: astropy-2.0.3-py36h14c3975_0 ...
# installing: bkcharts-0.2-py36h735825a_0 ...
# installing: bokeh-0.12.13-py36h2f9c1c0_0 ...
# installing: flask-0.12.2-py36hb24657c_0 ...
# installing: jupyter_client-5.2.2-py36_0 ...
# installing: nbformat-4.4.0-py36h31c9010_0 ...
# installing: pip-9.0.1-py36h6c6f9ce_4 ...
# installing: prompt_toolkit-1.0.15-py36h17d85b1_0 ...
# installing: pylint-1.8.2-py36_0 ...
# installing: pyopenssl-17.5.0-py36h20ba746_0 ...
# installing: statsmodels-0.8.0-py36h8533d0b_0 ...
# installing: dask-0.16.1-py36_0 ...
# installing: flask-cors-3.0.3-py36h2d857d3_0 ...
# installing: ipython-6.2.1-py36h88c514a_1 ...
# installing: nbconvert-5.3.1-py36hb41ffb7_0 ...
# installing: seaborn-0.8.1-py36hfad7ec4_0 ...
# installing: urllib3-1.22-py36hbe7ace6_0 ...
# installing: ipykernel-4.8.0-py36_0 ...
# installing: odo-0.5.1-py36h90ed295_0 ...
# installing: requests-2.18.4-py36he2e5f8d_1 ...
# installing: scikit-image-0.13.1-py36h14c3975_1 ...
# installing: anaconda-client-1.6.9-py36_0 ...
# installing: blaze-0.11.3-py36h4e06776_0 ...
# installing: jupyter_console-5.2.0-py36he59e554_1 ...
# installing: notebook-5.4.0-py36_0 ...
# installing: qtconsole-4.3.1-py36h8f73b5b_0 ...
# installing: sphinx-1.6.6-py36_0 ...
# installing: anaconda-project-0.8.2-py36h44fb852_0 ...
# installing: jupyterlab_launcher-0.10.2-py36_0 ...
# installing: numpydoc-0.7.0-py36h18f165f_0 ...
# installing: widgetsnbextension-3.1.0-py36_0 ...
# installing: anaconda-navigator-1.7.0-py36_0 ...
# installing: ipywidgets-7.1.1-py36_0 ...
# installing: jupyterlab-0.31.5-py36_0 ...
# installing: spyder-3.2.6-py36_0 ...
# installing: _ipyw_jlab_nb_ext_conf-0.1.0-py36he11e457_0 ...
# installing: jupyter-1.0.0-py36_4 ...
# installing: anaconda-5.1.0-py36_2 ...
# installing: conda-4.4.10-py36_0 ...
# installing: conda-build-3.4.1-py36_0 ...
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda3: /usr/local
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     setuptools-46.4.0          |           py36_0         646 KB
#     python-3.6.10              |       h7579374_2        33.9 MB
#     certifi-2020.4.5.1         |           py36_0         159 KB
#     libffi-3.3                 |       he6710b0_1          54 KB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     pip-20.0.2                 |           py36_3         1.9 MB
#     libedit-3.1.20181209       |       hc058e9b_0         188 KB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     zlib-1.2.11                |       h7b6447c_3         120 KB
#     readline-8.0               |       h7b6447c_0         428 KB
#     ca-certificates-2020.1.1   |                0         132 KB
#     _libgcc_mutex-0.1          |             main           3 KB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     tk-8.6.8                   |       hbc83047_0         3.1 MB
#     sqlite-3.31.1              |       h62c20be_1         2.0 MB
#     wheel-0.34.2               |           py36_0          49 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     ------------------------------------------------------------
#                                            Total:        60.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _libgcc_mutex:    0.1-main
#     ld_impl_linux-64: 2.33.1-h53a641e_7
#
# The following packages will be UPDATED:
#
#     ca-certificates:  2017.08.26-h1d4fec5_0 --> 2020.1.1-0
#     certifi:          2018.1.18-py36_0      --> 2020.4.5.1-py36_0
#     libedit:          3.1-heed3624_0        --> 3.1.20181209-hc058e9b_0
#     libffi:           3.2.1-hd88cf55_4      --> 3.3-he6710b0_1
#     libgcc-ng:        7.2.0-h7cc24e2_2      --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:     7.2.0-h7a57d05_2      --> 9.1.0-hdf63c60_0
#     ncurses:          6.0-h9df7e31_2        --> 6.2-he6710b0_1
#     openssl:          1.0.2n-hb7f436b_0     --> 1.1.1g-h7b6447c_0
#     pip:              9.0.1-py36h6c6f9ce_4  --> 20.0.2-py36_3
#     python:           3.6.4-hc3d631a_1      --> 3.6.10-h7579374_2
#     readline:         7.0-ha6073c6_4        --> 8.0-h7b6447c_0
#     setuptools:       38.4.0-py36_0         --> 46.4.0-py36_0
#     sqlite:           3.22.0-h1bed415_0     --> 3.31.1-h62c20be_1
#     tk:               8.6.7-hc745277_3      --> 8.6.8-hbc83047_0
#     wheel:            0.30.0-py36hfd4bba0_1 --> 0.34.2-py36_0
#     xz:               5.2.3-h55aa19d_2      --> 5.2.5-h7b6447c_0
#     zlib:             1.2.11-ha838bed_2     --> 1.2.11-h7b6447c_3
#
#
# Downloading and Extracting Packages
# setuptools 46.4.0: 100% 1.0/1 [00:00<00:00,  3.05it/s]
# python 3.6.10: 100% 1.0/1 [00:09<00:00,  9.14s/it]
# certifi 2020.4.5.1: 100% 1.0/1 [00:00<00:00, 14.11it/s]
# libffi 3.3: 100% 1.0/1 [00:00<00:00, 22.06it/s]
# libgcc-ng 9.1.0: 100% 1.0/1 [00:02<00:00,  2.44s/it]
# pip 20.0.2: 100% 1.0/1 [00:00<00:00,  1.11it/s]
# libedit 3.1.20181209: 100% 1.0/1 [00:00<00:00, 10.10it/s]
# xz 5.2.5: 100% 1.0/1 [00:00<00:00,  5.03it/s]
# zlib 1.2.11: 100% 1.0/1 [00:00<00:00, 13.86it/s]
# readline 8.0: 100% 1.0/1 [00:00<00:00,  5.36it/s]
# ca-certificates 2020.1.1: 100% 1.0/1 [00:00<00:00, 16.65it/s]
# _libgcc_mutex 0.1: 100% 1.0/1 [00:00<00:00, 30.33it/s]
# ncurses 6.2: 100% 1.0/1 [00:00<00:00,  1.01it/s]
# openssl 1.1.1g: 100% 1.0/1 [00:01<00:00,  1.26s/it]
# ld_impl_linux-64 2.33.1: 100% 1.0/1 [00:00<00:00,  3.42it/s]
# tk 8.6.8: 100% 1.0/1 [00:01<00:00,  1.10s/it]
# sqlite 3.31.1: 100% 1.0/1 [00:00<00:00,  1.61it/s]
# wheel 0.34.2: 100% 1.0/1 [00:00<00:00, 18.99it/s]
# libstdcxx-ng 9.1.0: 100% 1.0/1 [00:01<00:00,  1.23s/it]
# done
# done
# done
# -
# WARNING: The remote server could not find the noarch directory for the
# requested channel with url: https://conda.anaconda.org/pip
#
# It is possible you have given conda an invalid channel. Please double-check
# your conda configuration using `conda config --show`.
#
# If the requested url is in fact a valid conda channel, please request that the
# channel administrator create `noarch/repodata.json` and associated
# `noarch/repodata.json.bz2` files, even if `noarch/repodata.json` is empty.
# $ mkdir noarch
# $ echo '{}' > noarch/repodata.json
# $ bzip2 -k noarch/repodata.json
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
# Collecting mordred
#   Downloading https://files.pythonhosted.org/packages/93/3d/26c908ece761adafcea06320bf8fe73f4de69979273fb164226dc6038c39/mordred-1.2.0.tar.gz (128kB)
#      |████████████████████████████████| 133kB 2.8MB/s
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.6/dist-packages (from mordred) (1.12.0)
# Requirement already satisfied: numpy==1.* in /usr/local/lib/python3.6/dist-packages (from mordred) (1.18.4)
# Requirement already satisfied: networkx==2.* in /usr/local/lib/python3.6/dist-packages (from mordred) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx==2.*->mordred) (4.4.2)
# Building wheels for collected packages: mordred
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-cp36-none-any.whl size=176721 sha256=0a14c0a7c735000ac07c857f8108bc8d9db56f241d6cf46cd9e22ed045ccb7f3
#   Stored in directory: /root/.cache/pip/wheels/ac/74/3f/2fd81b1187013f2eadb15620434813f1824c4c03b7bd1f94f6
# Successfully built mordred
# Installing collected packages: mordred
# Successfully installed mordred-1.2.0
# Collecting oddt
#   Downloading https://files.pythonhosted.org/packages/5c/98/0e6e00bf226b2f005197e1913f1572e91382f882cb89dd574af85c42734b/oddt-0.7.tar.gz (2.3MB)
#      |████████████████████████████████| 2.3MB 2.8MB/s
# Collecting pubchempy
#   Downloading https://files.pythonhosted.org/packages/aa/fb/8de3aa9804b614dbc8dc5c16ed061d819cc360e0ddecda3dcd01c1552339/PubChemPy-1.0.4.tar.gz
# Collecting numpydoc
#   Downloading https://files.pythonhosted.org/packages/3a/43/2402fd1f63992a52f88e3b169d59674617013bf7f1ad0cd7d842eafd0c58/numpydoc-1.0.0-py3-none-any.whl (47kB)
#      |████████████████████████████████| 51kB 7.1MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from oddt) (1.12.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from oddt) (1.18.4)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.6/dist-packages (from oddt) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from oddt) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.9.4 in /usr/local/lib/python3.6/dist-packages (from oddt) (0.15.1)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from oddt) (1.0.4)
# Requirement already satisfied: sphinx>=1.6.5 in /usr/local/lib/python3.6/dist-packages (from numpydoc->oddt) (1.8.5)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.6/dist-packages (from numpydoc->oddt) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->oddt) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->oddt) (2018.9)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (2.0.0)
# Requirement already satisfied: docutils>=0.11 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (0.15.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (47.1.1)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (1.2.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (0.7.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (20.4)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (2.8.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (2.23.0)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (1.2.0)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.6/dist-packages (from sphinx>=1.6.5->numpydoc->oddt) (2.1.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.3->numpydoc->oddt) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->sphinx>=1.6.5->numpydoc->oddt) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx>=1.6.5->numpydoc->oddt) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx>=1.6.5->numpydoc->oddt) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx>=1.6.5->numpydoc->oddt) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->sphinx>=1.6.5->numpydoc->oddt) (2020.4.5.1)
# Building wheels for collected packages: oddt, pubchempy
#   Building wheel for oddt (setup.py) ... done
#   Created wheel for oddt: filename=oddt-0.7-py2.py3-none-any.whl size=2409545 sha256=739905b59438e21d9e6a8fdb1d775b9511fdbad661a6b0dce18437920b26cca7
#   Stored in directory: /root/.cache/pip/wheels/fe/66/9f/cf08a706b47cf8de6cca9b406801acdb3c3908ab481aa4a373
#   Building wheel for pubchempy (setup.py) ... done
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-cp36-none-any.whl size=13825 sha256=4e3f800b9f94f5b75371d5343ef38296ce26af43dd92e1880333155eebe4f163
#   Stored in directory: /root/.cache/pip/wheels/10/4d/51/6b843681a9a5aef35f0d0fbce243de46f85080036e16118752
# Successfully built oddt pubchempy
# Installing collected packages: numpydoc, oddt, pubchempy
# Successfully installed numpydoc-1.0.0 oddt-0.7 pubchempy-1.0.4
# Collecting biopython
#   Downloading https://files.pythonhosted.org/packages/a8/66/134dbd5f885fc71493c61b6cf04c9ea08082da28da5ed07709b02857cbd0/biopython-1.77-cp36-cp36m-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 2.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython) (1.18.4)
# Installing collected packages: biopython
# Successfully installed biopython-1.77
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.0.4               |   py36h830a2c2_0        10.1 MB  conda-forge
#     numpy-1.18.4               |   py36h7314795_0         5.2 MB  conda-forge
#     libopenblas-0.3.7          |       h5ec1e0e_6         7.6 MB  conda-forge
#     pycairo-1.18.0             |py36h1b9232e_1000          74 KB  conda-forge
#     libcblas-3.8.0             |      14_openblas          10 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     libblas-3.8.0              |      14_openblas          10 KB  conda-forge
#     boost-1.66.0               |           py36_1         317 KB  conda-forge
#     boost-cpp-1.66.0           |                1        18.8 MB  conda-forge
#     liblapack-3.8.0            |      14_openblas          10 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     rdkit-2018.03.3            |   py36hf2429ea_1        19.4 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        64.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     boost:           1.66.0-py36_1            conda-forge
#     boost-cpp:       1.66.0-1                 conda-forge
#     libblas:         3.8.0-14_openblas        conda-forge
#     libcblas:        3.8.0-14_openblas        conda-forge
#     liblapack:       3.8.0-14_openblas        conda-forge
#     libopenblas:     0.3.7-h5ec1e0e_6         conda-forge
#     pycairo:         1.18.0-py36h1b9232e_1000 conda-forge
#     python_abi:      3.6-1_cp36m              conda-forge
#     rdkit:           2018.03.3-py36hf2429ea_1 conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                           --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0                    --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     numpy:           1.14.0-py36h3dfced4_1                --> 1.18.4-py36h7314795_0     conda-forge
#     openssl:         1.1.1g-h7b6447c_0                    --> 1.1.1g-h516909a_0         conda-forge
#     pandas:          0.22.0-py36hf484d3e_0                --> 1.0.4-py36h830a2c2_0      conda-forge
#
#
# Downloading and Extracting Packages
# pandas 1.0.4: 100% 1.0/1 [00:04<00:00,  4.30s/it]
# numpy 1.18.4: 100% 1.0/1 [00:02<00:00,  2.14s/it]
# libopenblas 0.3.7: 100% 1.0/1 [00:02<00:00,  2.67s/it]
# pycairo 1.18.0: 100% 1.0/1 [00:00<00:00,  2.51it/s]
# libcblas 3.8.0: 100% 1.0/1 [00:00<00:00, 29.57it/s]
# ca-certificates 2020.4.5.1: 100% 1.0/1 [00:00<00:00, 15.80it/s]
# certifi 2020.4.5.1: 100% 1.0/1 [00:00<00:00, 14.70it/s]
# python_abi 3.6: 100% 1.0/1 [00:00<00:00, 24.79it/s]
# libblas 3.8.0: 100% 1.0/1 [00:00<00:00, 22.38it/s]
# boost 1.66.0: 100% 1.0/1 [00:00<00:00,  1.74it/s]
# boost-cpp 1.66.0: 100% 1.0/1 [00:15<00:00, 15.07s/it]
# liblapack 3.8.0: 100% 1.0/1 [00:00<00:00, 16.73it/s]
# openssl 1.1.1g: 100% 1.0/1 [00:00<00:00,  1.51it/s]
# rdkit 2018.03.3: 100% 1.0/1 [00:08<00:00,  8.22s/it]
# done
# done
# done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libopenbabel4v5
# The following NEW packages will be installed:
#   libopenbabel4v5 openbabel
# 0 upgraded, 2 newly installed, 0 to remove and 32 not upgraded.
# Need to get 2,766 kB of archives.
# After this operation, 11.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenbabel4v5 amd64 2.3.2+dfsg-3build1 [2,664 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openbabel amd64 2.3.2+dfsg-3build1 [102 kB]
# Fetched 2,766 kB in 3s (990 kB/s)
# Selecting previously unselected package libopenbabel4v5.
# (Reading database ... 144467 files and directories currently installed.)
# Preparing to unpack .../libopenbabel4v5_2.3.2+dfsg-3build1_amd64.deb ...
# Unpacking libopenbabel4v5 (2.3.2+dfsg-3build1) ...
# Selecting previously unselected package openbabel.
# Preparing to unpack .../openbabel_2.3.2+dfsg-3build1_amd64.deb ...
# Unpacking openbabel (2.3.2+dfsg-3build1) ...
# Setting up libopenbabel4v5 (2.3.2+dfsg-3build1) ...
# Setting up openbabel (2.3.2+dfsg-3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting biopython
#   Using cached biopython-1.77-cp36-cp36m-manylinux1_x86_64.whl (2.3 MB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from biopython) (1.18.4)
# Installing collected packages: biopython
# Successfully installed biopython-1.77
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   removed specs:
#     - sympy
#
#
# The following packages will be REMOVED:
#
#     anaconda:        5.1.0-py36_2
#     sympy:           1.1.1-py36hc6d1c1c_0
#
# The following packages will be UPDATED:
#
#     certifi:         2020.4.5.1-py36h9f0ad1d_0 conda-forge --> 2020.4.5.1-py36_0
#     openssl:         1.1.1g-h516909a_0         conda-forge --> 1.1.1g-h7b6447c_0
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.4.5.1-hecc5488_0     conda-forge --> 2020.1.1-0
#
# done
# done
# done
# Collecting qiskit
#   Downloading qiskit-0.19.3.tar.gz (3.9 kB)
# Collecting qiskit-terra==0.14.1
#   Downloading qiskit_terra-0.14.1-cp36-cp36m-manylinux2010_x86_64.whl (6.7 MB)
#      |████████████████████████████████| 6.7 MB 2.6 MB/s
# Collecting qiskit-aer==0.5.2
#   Downloading qiskit_aer-0.5.2-cp36-cp36m-manylinux2010_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.4 MB/s
# Collecting qiskit-ibmq-provider==0.7.2
#   Downloading qiskit_ibmq_provider-0.7.2-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 62.8 MB/s
# Collecting qiskit-ignis==0.3.0
#   Downloading qiskit_ignis-0.3.0-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 54.3 MB/s
# Collecting qiskit-aqua==0.7.1
#   Downloading qiskit_aqua-0.7.1-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 50.8 MB/s
# Collecting scipy>=1.4
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
#      |████████████████████████████████| 26.1 MB 24 kB/s
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.6/site-packages (from qiskit-terra==0.14.1->qiskit) (5.4.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.6/site-packages (from qiskit-terra==0.14.1->qiskit) (2.6.0)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.6.1-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.5 MB/s
# Collecting networkx>=2.2; python_version > "3.5"
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 56.9 MB/s
# Collecting python-dateutil>=2.8.0
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 63.5 MB/s
# Collecting fastjsonschema>=2.10
#   Downloading fastjsonschema-2.14.4-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.6/site-packages (from qiskit-terra==0.14.1->qiskit) (1.18.4)
# Collecting retworkx>=0.3.2
#   Downloading retworkx-0.3.4-cp36-cp36m-manylinux2010_x86_64.whl (763 kB)
#      |████████████████████████████████| 763 kB 57.1 MB/s
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.6/site-packages (from qiskit-terra==0.14.1->qiskit) (3.10)
# Collecting sympy>=1.3
#   Downloading sympy-1.6-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 48.3 MB/s
# Collecting python-constraint>=1.4
#   Downloading python-constraint-1.4.0.tar.bz2 (18 kB)
# Collecting dill>=0.3
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 57.5 MB/s
# Collecting marshmallow-polyfield<6,>=5.7
#   Downloading marshmallow-polyfield-5.9.tar.gz (8.5 kB)
# Requirement already satisfied: cython>=0.27.1 in /usr/local/lib/python3.6/site-packages (from qiskit-aer==0.5.2->qiskit) (0.27.3)
# Collecting pybind11>=2.4
#   Downloading pybind11-2.5.0-py2.py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 55.6 MB/s
# Collecting requests-ntlm>=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Collecting nest-asyncio!=1.1.0,>=1.0.0
#   Downloading nest_asyncio-1.3.3-py3-none-any.whl (4.7 kB)
# Collecting requests>=2.19
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.9 MB/s
# Collecting websockets<8,>=7
#   Downloading websockets-7.0-cp36-cp36m-manylinux1_x86_64.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.8 MB/s
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.6/site-packages (from qiskit-ibmq-provider==0.7.2->qiskit) (1.22)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.6/site-packages (from qiskit-ignis==0.3.0->qiskit) (46.4.0.post20200518)
# Collecting scikit-learn>=0.20.0
#   Downloading scikit_learn-0.23.1-cp36-cp36m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 50.1 MB/s
# Collecting fastdtw
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#      |████████████████████████████████| 133 kB 62.8 MB/s
# Collecting docplex
#   Downloading docplex-2.14.186.tar.gz (572 kB)
#      |████████████████████████████████| 572 kB 49.6 MB/s
# Collecting quandl
#   Downloading Quandl-3.5.0-py2.py3-none-any.whl (25 kB)
# Collecting pyscf; sys_platform != "win32"
#   Downloading pyscf-1.7.2.post2-cp36-cp36m-manylinux1_x86_64.whl (26.0 MB)
#      |████████████████████████████████| 26.0 MB 1.3 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/site-packages (from qiskit-aqua==0.7.1->qiskit) (2.7.1)
# Collecting dlx
#   Downloading dlx-1.0.4.tar.gz (5.5 kB)
# Collecting decorator>=4.3.0
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.8.0->qiskit-terra==0.14.1->qiskit) (1.11.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/site-packages (from sympy>=1.3->qiskit-terra==0.14.1->qiskit) (1.0.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.6/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit) (2.1.4)
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit) (2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.7.2->qiskit) (3.0.4)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-0.15.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 55.9 MB/s
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.6/site-packages (from quandl->qiskit-aqua==0.7.1->qiskit) (1.0.4)
# Collecting more-itertools
#   Downloading more_itertools-8.3.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 3.1 MB/s
# Collecting inflection>=0.3.1
#   Downloading inflection-0.4.0-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: asn1crypto>=0.21.0 in /usr/local/lib/python3.6/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit) (0.24.0)
# Requirement already satisfied: cffi>=1.7 in /usr/local/lib/python3.6/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit) (1.11.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas>=0.14->quandl->qiskit-aqua==0.7.1->qiskit) (2017.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/site-packages (from cffi>=1.7->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.7.2->qiskit) (2.18)
# Building wheels for collected packages: qiskit, python-constraint, dill, marshmallow-polyfield, fastdtw, docplex, dlx
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.19.3-py3-none-any.whl size=2898 sha256=adb94bf23ad6b4961c8a9f2a242df9464a2ee6f929d1be30903f5fbfc2f31fc0
#   Stored in directory: /root/.cache/pip/wheels/68/ba/b0/78177cd3f8cba974755148c5901a9abc2696660246187e0efd
#   Building wheel for python-constraint (setup.py) ... done
#   Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24080 sha256=abe7b3fb865b85bee58a743007d173a7dea755ddb8325f723a00002b017fe079
#   Stored in directory: /root/.cache/pip/wheels/c2/e2/65/6222764e3e5b677acdb04b592abab7e15140a70baace656d81
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=4d8e09b0880bc026478dc2b2074c87d87a277d424beea8c23fad0398ff3a3e23
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
#   Building wheel for marshmallow-polyfield (setup.py) ... done
#   Created wheel for marshmallow-polyfield: filename=marshmallow_polyfield-5.9-py3-none-any.whl size=8535 sha256=253fc794a78dbb020d74e68a5d98a9dd5bab491dbd4364d5243abd14200d8277
#   Stored in directory: /root/.cache/pip/wheels/9a/54/a7/4e0d56296d25c6eae6b1f213db626d8a4828228406abb73918
#   Building wheel for fastdtw (setup.py) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp36-cp36m-linux_x86_64.whl size=391289 sha256=0bae1ea9b83d9e0ff1dea6fc1f27198534fbce1a7c1b6e91fbeac65178d51a7f
#   Stored in directory: /root/.cache/pip/wheels/50/66/7a/7c98f31ea8ecc3a04a5b20ec6b48fbdf02c899034e95cc1ede
#   Building wheel for docplex (setup.py) ... done
#   Created wheel for docplex: filename=docplex-2.14.186-py3-none-any.whl size=634441 sha256=f1f5e133bf1e667200fdda9e5f27dc7c1414f76397059f8786c10888c5155f7f
#   Stored in directory: /root/.cache/pip/wheels/af/8a/77/21b87b28bbef8aeea189643cb281511d584d1f30e57378dd9c
#   Building wheel for dlx (setup.py) ... done
#   Created wheel for dlx: filename=dlx-1.0.4-py3-none-any.whl size=5709 sha256=e1851de1220d4f9dba5bc72a64467a36995d70d867b0ee4fe83710dba3d6fef1
#   Stored in directory: /root/.cache/pip/wheels/ad/a3/52/859d389366d76e9e371e5a2dabefde5da7678c0032f008ca0a
# Successfully built qiskit python-constraint dill marshmallow-polyfield fastdtw docplex dlx
# Installing collected packages: scipy, marshmallow, decorator, networkx, python-dateutil, fastjsonschema, retworkx, sympy, python-constraint, dill, marshmallow-polyfield, qiskit-terra, pybind11, qiskit-aer, requests, ntlm-auth, requests-ntlm, nest-asyncio, websockets, qiskit-ibmq-provider, qiskit-ignis, threadpoolctl, joblib, scikit-learn, fastdtw, docplex, more-itertools, inflection, quandl, pyscf, dlx, qiskit-aqua, qiskit
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.0.0
#     Uninstalling scipy-1.0.0:
#       Successfully uninstalled scipy-1.0.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.2.1
#     Uninstalling decorator-4.2.1:
#       Successfully uninstalled decorator-4.2.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.1
#     Uninstalling networkx-2.1:
#       Successfully uninstalled networkx-2.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.6.1
#     Uninstalling python-dateutil-2.6.1:
#       Successfully uninstalled python-dateutil-2.6.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.19.1
#     Uninstalling scikit-learn-0.19.1:
#       Successfully uninstalled scikit-learn-0.19.1
# Successfully installed decorator-4.4.2 dill-0.3.1.1 dlx-1.0.4 docplex-2.14.186 fastdtw-0.3.4 fastjsonschema-2.14.4 inflection-0.4.0 joblib-0.15.1 marshmallow-3.6.1 marshmallow-polyfield-5.9 more-itertools-8.3.0 nest-asyncio-1.3.3 networkx-2.4 ntlm-auth-1.4.0 pybind11-2.5.0 pyscf-1.7.2.post2 python-constraint-1.4.0 python-dateutil-2.8.1 qiskit-0.19.3 qiskit-aer-0.5.2 qiskit-aqua-0.7.1 qiskit-ibmq-provider-0.7.2 qiskit-ignis-0.3.0 qiskit-terra-0.14.1 quandl-3.5.0 requests-2.23.0 requests-ntlm-1.1.0 retworkx-0.3.4 scikit-learn-0.23.1 scipy-1.4.1 sympy-1.6 threadpoolctl-2.1.0 websockets-7.0
# Collecting pennylane
#   Downloading PennyLane-0.9.0-py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 2.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from pennylane) (1.18.4)
# Collecting semantic-version==2.6
#   Downloading semantic_version-2.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/site-packages (from pennylane) (1.4.1)
# Collecting autograd
#   Downloading autograd-1.3.tar.gz (38 kB)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting toml
#   Downloading toml-0.10.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/site-packages (from pennylane) (2.4)
# Collecting future>=0.15.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 8.4 MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx->pennylane) (4.4.2)
# Building wheels for collected packages: autograd, future
#   Building wheel for autograd (setup.py) ... done
#   Created wheel for autograd: filename=autograd-1.3-py3-none-any.whl size=47990 sha256=8f373a6540801bb11299cac7b559337d67a65056e4224bf375174d17efe8557f
#   Stored in directory: /root/.cache/pip/wheels/b2/a5/3c/929b91003a3b75a175ccba7cef35200a1890cdb46903f18072
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=31ddd924ca6f0c92f25ad2c2c30c48ae0d3c4068bc0cc90bf8ebb64b0c4e02f0
#   Stored in directory: /root/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
# Successfully built autograd future
# Installing collected packages: semantic-version, future, autograd, appdirs, toml, pennylane
# Successfully installed appdirs-1.4.4 autograd-1.3 future-0.18.2 pennylane-0.9.0 semantic-version-2.6.0 toml-0.10.1
# CPU times: user 1.84 s, sys: 416 ms, total: 2.26 s
# Wall time: 6min 20s

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1n7x4fP4A85rDDUcQ9nrnS9l2lu9pZWPm
# !gdown https://drive.google.com/uc?id=1MKQnbbzw2l92TrImG8F0qpQuCa4luZG8
# !unzip data.zip
# !unzip PyBioMed-1.0.zip
# %cd PyBioMed-1.0
# !python3 setup.py install
# %cd ..
# Out:
# Collecting gdown
#   Downloading gdown-3.11.0.tar.gz (8.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from gdown) (1.11.0)
# Collecting tqdm
#   Downloading tqdm-4.46.0-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.6/site-packages (from gdown) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/site-packages (from gdown) (2.0.13)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests[socks]->gdown) (1.22)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests[socks]->gdown) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests[socks]->gdown) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/site-packages (from requests[socks]->gdown) (1.6.7)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.11.0-py3-none-any.whl size=9619 sha256=60c7828301a0e0ae0113c36a95268cdb6d3df730f0c9eaa70e25d9b834d27913
#   Stored in directory: /root/.cache/pip/wheels/38/fe/03/8ea0c23ae5185b924065e9e5cf7b054268d4f73ab7c06946aa
# Successfully built gdown
# Installing collected packages: tqdm, gdown
# Successfully installed gdown-3.11.0 tqdm-4.46.0
# Downloading...
# From: https://drive.google.com/uc?id=1n7x4fP4A85rDDUcQ9nrnS9l2lu9pZWPm
# To: /content/data.zip
# 141MB [00:02, 51.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MKQnbbzw2l92TrImG8F0qpQuCa4luZG8
# To: /content/PyBioMed-1.0.zip
# 22.4MB [00:00, 114MB/s]
# Archive:  data.zip
#   inflating: positive_pair.csv
#    creating: __MACOSX/
#   inflating: __MACOSX/._positive_pair.csv
#   inflating: protein_descriptor.csv
#   inflating: __MACOSX/._protein_descriptor.csv
#   inflating: molecule_descriptor_new.csv
#   inflating: __MACOSX/._molecule_descriptor_new.csv
#   inflating: negative_pair.csv
#   inflating: __MACOSX/._negative_pair.csv
# Archive:  PyBioMed-1.0.zip
#    creating: PyBioMed-1.0/
#    creating: PyBioMed-1.0/build/
#    creating: PyBioMed-1.0/build/lib/
#    creating: PyBioMed-1.0/build/lib/PyBioMed/
#    creating: PyBioMed-1.0/build/lib/PyBioMed/doc/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1atp (1).pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1atp.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1efz.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1f88 (1).ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1f88.ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/1f88.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/application (1).rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/application.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/conf.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/Documentation.pdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/PyBioMed Chem.pdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/PyBioMed DNA.pdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/PyBioMed Interaction.pdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Descriptor/PyBioMed Protein.pdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/download.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/index.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/make.bat
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/Makefile
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/modules (1).rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/modules.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/overview.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/test.rst
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/doc/User_guide.rst
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/caco2/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/caco2/caco2.xlsx
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/dna/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/dna/H_sapiens_neg.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/dna/H_sapiens_pos.fasta
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/dpi/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/dpi/DPI_SMIs.xlsx
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/dpi/Enzyme.xls
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/dpi/hsa_seqs_all.tsv
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/solubility/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/solubility/Solubility-total.xlsx
#    creating: PyBioMed-1.0/build/lib/PyBioMed/example/subcell/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/subcell/Cytoplasm_seq.txt
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/example/subcell/Nuclear_seq.txt
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/Pydna.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/1atp.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/1efz (1).pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/1efz.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/1f88.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/mmc3 (1).data
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/mmc3.data
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/mmc4 (1).data
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/mmc4.data
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNA (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNA.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAac (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAac.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAacutil.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAnac.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAnacutil (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAnacutil.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNApsenac (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNApsenac.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNApsenacutil.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAutil (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/PyDNAutil.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/__init__ (1).py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyDNA/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1atp.ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1atp.pdb
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1efz.ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1efz.pdb
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1f88.ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/1f88.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/GetDNA.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/Getmol.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/GetProtein.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyGetMol/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyInteraction/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/Pyinteraction.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyInteraction/PyInteraction.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyInteraction/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/Pymolecule.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/AtomProperty.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/AtomTypes.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/basak.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/bcut.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/cats2d.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/charge.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/connectivity.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/constitution.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/Crippen.txt
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/estate.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/fingerprint.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/geary.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/ghosecrippen.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/kappa.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/MinimalFeatures.fdef
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/moe.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/molproperty.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/moran.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/moreaubroto.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/PubChemFingerprints.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/Scaffolds.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/topology.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyMolecule/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyDNAutil.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPreTools (1).py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPreTools.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPretreatDNA.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPretreatMol.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPretreatMolutil.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/PyPretreatPro.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/PyPretreat/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/Pyprotein.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/AAComposition.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/AAIndex.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/aaindex1
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/aaindex2
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/aaindex3
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/Autocorrelation.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/ConjointTriad.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/CTD.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/GetProteinFromUniprot.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/GetSubSeq.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/ProCheck.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/PseudoAAC.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/PyProtein.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/PyProteinAAComposition.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/PyProteinAAIndex.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/QuasiSequenceOrder.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/PyProtein/__init__.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/test/
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/test/1atp.ent.gz
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/1atp.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/1efz.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/1f88.pdb
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test.py
#    creating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/drug.inchi
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/drug.mol
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/drug.sdf
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/drug.smi
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/example.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/hs.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/neg.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/pos.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/protein.fasta
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/target.txt
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_data/test.mol
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyBioMed.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyDNA.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyGetMol.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyInteration.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyMolecule.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyPretreat.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/test/test_PyProtein.py
#  extracting: PyBioMed-1.0/build/lib/PyBioMed/test/__init__.py
#   inflating: PyBioMed-1.0/build/lib/PyBioMed/__init__.py
#   inflating: PyBioMed-1.0/PKG-INFO
#    creating: PyBioMed-1.0/PyBioMed/
#    creating: PyBioMed-1.0/PyBioMed/.vscode/
#   inflating: PyBioMed-1.0/PyBioMed/.vscode/settings.json
#    creating: PyBioMed-1.0/PyBioMed/doc/
#   inflating: PyBioMed-1.0/PyBioMed/doc/1atp(1).pdb
#   inflating: PyBioMed-1.0/PyBioMed/doc/1atp.pdb
#   inflating: PyBioMed-1.0/PyBioMed/doc/1efz.pdb
#   inflating: PyBioMed-1.0/PyBioMed/doc/1f88.ent(1).gz
#   inflating: PyBioMed-1.0/PyBioMed/doc/1f88.ent.gz
#   inflating: PyBioMed-1.0/PyBioMed/doc/1f88.pdb
#   inflating: PyBioMed-1.0/PyBioMed/doc/application(1).rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/application.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/conf.py
#    creating: PyBioMed-1.0/PyBioMed/doc/Descriptor/
#   inflating: PyBioMed-1.0/PyBioMed/doc/Descriptor/Documentation.pdf
#   inflating: PyBioMed-1.0/PyBioMed/doc/Descriptor/PyBioMed Chem.pdf
#   inflating: PyBioMed-1.0/PyBioMed/doc/Descriptor/PyBioMed DNA.pdf
#   inflating: PyBioMed-1.0/PyBioMed/doc/Descriptor/PyBioMed Interaction.pdf
#   inflating: PyBioMed-1.0/PyBioMed/doc/Descriptor/PyBioMed Protein.pdf
#   inflating: PyBioMed-1.0/PyBioMed/doc/download.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/index.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/make.bat
#   inflating: PyBioMed-1.0/PyBioMed/doc/Makefile
#   inflating: PyBioMed-1.0/PyBioMed/doc/modules(1).rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/modules.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/overview.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/test.rst
#   inflating: PyBioMed-1.0/PyBioMed/doc/User_guide.rst
#    creating: PyBioMed-1.0/PyBioMed/example/
#    creating: PyBioMed-1.0/PyBioMed/example/caco2/
#   inflating: PyBioMed-1.0/PyBioMed/example/caco2/caco2.xlsx
#    creating: PyBioMed-1.0/PyBioMed/example/dna/
#   inflating: PyBioMed-1.0/PyBioMed/example/dna/H_sapiens_neg.fasta
#   inflating: PyBioMed-1.0/PyBioMed/example/dna/H_sapiens_pos.fasta
#    creating: PyBioMed-1.0/PyBioMed/example/dpi/
#   inflating: PyBioMed-1.0/PyBioMed/example/dpi/DPI_SMIs.xlsx
#   inflating: PyBioMed-1.0/PyBioMed/example/dpi/Enzyme.xls
#   inflating: PyBioMed-1.0/PyBioMed/example/dpi/hsa_seqs_all.tsv
#    creating: PyBioMed-1.0/PyBioMed/example/solubility/
#   inflating: PyBioMed-1.0/PyBioMed/example/solubility/Solubility-total.xlsx
#    creating: PyBioMed-1.0/PyBioMed/example/subcell/
#   inflating: PyBioMed-1.0/PyBioMed/example/subcell/Cytoplasm_seq.txt
#   inflating: PyBioMed-1.0/PyBioMed/example/subcell/Nuclear_seq.txt
#    creating: PyBioMed-1.0/PyBioMed/PyDNA/
#   inflating: PyBioMed-1.0/PyBioMed/Pydna.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/1atp.pdb
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/1efz(1).pdb
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/1efz.pdb
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/1f88.pdb
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/mmc3(1).data
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/mmc3.data
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/mmc4(1).data
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/mmc4.data
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNA(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNA.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAac(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAac.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAacutil.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAnac.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAnacutil(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAnacutil.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNApsenac(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNApsenac.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNApsenacutil.py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAutil(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyDNA/PyDNAutil.py
#  extracting: PyBioMed-1.0/PyBioMed/PyDNA/__init__(1).py
#  extracting: PyBioMed-1.0/PyBioMed/PyDNA/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyGetMol/
#  extracting: PyBioMed-1.0/PyBioMed/PyGetMol/1atp.ent.gz
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/1atp.pdb
#  extracting: PyBioMed-1.0/PyBioMed/PyGetMol/1efz.ent.gz
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/1efz.pdb
#  extracting: PyBioMed-1.0/PyBioMed/PyGetMol/1f88.ent.gz
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/1f88.pdb
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/GetDNA.py
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/Getmol.py
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/GetProtein.py
#  extracting: PyBioMed-1.0/PyBioMed/PyGetMol/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyGetMol/__pycache__/
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/__pycache__/Getmol.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyGetMol/__pycache__/__init__.cpython-36.pyc
#    creating: PyBioMed-1.0/PyBioMed/PyInteraction/
#   inflating: PyBioMed-1.0/PyBioMed/Pyinteraction.py
#   inflating: PyBioMed-1.0/PyBioMed/PyInteraction/PyInteraction.py
#  extracting: PyBioMed-1.0/PyBioMed/PyInteraction/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyMolecule/
#   inflating: PyBioMed-1.0/PyBioMed/Pymolecule.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/AtomProperty.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/AtomTypes.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/basak.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/bcut.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/cats2d.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/charge.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/connectivity.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/constitution.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/Crippen.txt
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/estate.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/fingerprint.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/geary.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/ghosecrippen.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/kappa.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/MinimalFeatures.fdef
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/moe.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/molproperty.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/moran.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/moreaubroto.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/PubChemFingerprints.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/Scaffolds.py
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/topology.py
#  extracting: PyBioMed-1.0/PyBioMed/PyMolecule/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/AtomProperty.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/AtomTypes.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/basak.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/bcut.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/cats2d.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/charge.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/connectivity.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/constitution.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/estate.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/kappa.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/molproperty.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/moreaubroto.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/PubChemFingerprints.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/Scaffolds.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyMolecule/__pycache__/__init__.cpython-36.pyc
#    creating: PyBioMed-1.0/PyBioMed/PyPretreat/
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyDNAutil.py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPreTools(1).py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPreTools.py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPretreatDNA.py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPretreatMol.py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPretreatMolutil.py
#   inflating: PyBioMed-1.0/PyBioMed/PyPretreat/PyPretreatPro.py
#  extracting: PyBioMed-1.0/PyBioMed/PyPretreat/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyProtein/
#   inflating: PyBioMed-1.0/PyBioMed/Pyprotein.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/AAComposition.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/AAIndex.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/aaindex1
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/aaindex2
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/aaindex3
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/Autocorrelation.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/ConjointTriad.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/CTD.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/GetProteinFromUniprot.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/GetSubSeq.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/ProCheck.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/PseudoAAC.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/PyProtein.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/PyProteinAAComposition.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/PyProteinAAIndex.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/QuasiSequenceOrder.py
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/AAComposition.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/AAIndex.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/Autocorrelation.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/ConjointTriad.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/CTD.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/PyProtein.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/PyProtein/__pycache__/__init__.cpython-36.pyc
#    creating: PyBioMed-1.0/PyBioMed/test/
#  extracting: PyBioMed-1.0/PyBioMed/test/1atp.ent.gz
#   inflating: PyBioMed-1.0/PyBioMed/test/1atp.pdb
#   inflating: PyBioMed-1.0/PyBioMed/test/1efz.pdb
#   inflating: PyBioMed-1.0/PyBioMed/test/1f88.pdb
#   inflating: PyBioMed-1.0/PyBioMed/test/test.py
#    creating: PyBioMed-1.0/PyBioMed/test/test_data/
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/drug.inchi
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/drug.mol
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/drug.sdf
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/drug.smi
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/example.fasta
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/hs.fasta
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/neg.fasta
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/pos.fasta
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/protein.fasta
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/target.txt
#   inflating: PyBioMed-1.0/PyBioMed/test/test_data/test.mol
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyBioMed.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyDNA.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyGetMol.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyInteration.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyMolecule.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyPretreat.py
#   inflating: PyBioMed-1.0/PyBioMed/test/test_PyProtein.py
#  extracting: PyBioMed-1.0/PyBioMed/test/__init__.py
#   inflating: PyBioMed-1.0/PyBioMed/__init__.py
#    creating: PyBioMed-1.0/PyBioMed/__pycache__/
#   inflating: PyBioMed-1.0/PyBioMed/__pycache__/Pymolecule.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/__pycache__/Pyprotein.cpython-36.pyc
#   inflating: PyBioMed-1.0/PyBioMed/__pycache__/__init__.cpython-36.pyc
#   inflating: PyBioMed-1.0/setup.py
# /content/PyBioMed-1.0
# /usr/local/lib/python3.6/distutils/dist.py:261: UserWarning: Unknown distribution option: 'zip_safe'
#   warnings.warn(msg)
# running install
# running build
# running build_py
# copying PyBioMed/PyDNA/PyDNApsenac(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/PyDNAac(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/PyDNAutil(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/mmc3(1).data -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/PyDNAnacutil(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/1efz(1).pdb -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/mmc4(1).data -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/__init__(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyDNA/PyDNA(1).py -> build/lib/PyBioMed/PyDNA
# copying PyBioMed/PyPretreat/PyPreTools(1).py -> build/lib/PyBioMed/PyPretreat
# copying PyBioMed/PyPretreat/PyPreTools.py -> build/lib/PyBioMed/PyPretreat
# copying PyBioMed/doc/1f88.ent(1).gz -> build/lib/PyBioMed/doc
# copying PyBioMed/doc/modules(1).rst -> build/lib/PyBioMed/doc
# copying PyBioMed/doc/1atp(1).pdb -> build/lib/PyBioMed/doc
# copying PyBioMed/doc/application(1).rst -> build/lib/PyBioMed/doc
# running install_lib
# creating /usr/local/lib/python3.6/site-packages/PyBioMed
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNA (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAutil (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAacutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAnacutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNApsenac(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNApsenacutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNApsenac (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc4 (1).data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNA.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/1efz (1).pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAac.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/1atp.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAac (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAnac.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAnacutil (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/__init__ (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAac(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAutil(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc3(1).data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNAnacutil(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/1efz(1).pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc4(1).data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc3.data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNApsenac.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/__init__(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc3 (1).data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/1f88.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/1efz.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/PyDNA(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/PyDNA/mmc4.data -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA
# copying build/lib/PyBioMed/Pymolecule.py -> /usr/local/lib/python3.6/site-packages/PyBioMed
# copying build/lib/PyBioMed/Pyinteraction.py -> /usr/local/lib/python3.6/site-packages/PyBioMed
# copying build/lib/PyBioMed/Pydna.py -> /usr/local/lib/python3.6/site-packages/PyBioMed
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPretreatMolutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPretreatPro.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyDNAutil.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPretreatDNA.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPreTools (1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPreTools(1).py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPretreatMol.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# copying build/lib/PyBioMed/PyPretreat/PyPreTools.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/PyProteinAAComposition.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/ConjointTriad.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/aaindex1 -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/GetProteinFromUniprot.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/PyProteinAAIndex.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/PseudoAAC.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/QuasiSequenceOrder.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/AAComposition.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/ProCheck.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/GetSubSeq.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/aaindex2 -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/Autocorrelation.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/CTD.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/aaindex3 -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/AAIndex.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# copying build/lib/PyBioMed/PyProtein/PyProtein.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example/dpi
# copying build/lib/PyBioMed/example/dpi/DPI_SMIs.xlsx -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/dpi
# copying build/lib/PyBioMed/example/dpi/Enzyme.xls -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/dpi
# copying build/lib/PyBioMed/example/dpi/hsa_seqs_all.tsv -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/dpi
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example/dna
# copying build/lib/PyBioMed/example/dna/H_sapiens_neg.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/dna
# copying build/lib/PyBioMed/example/dna/H_sapiens_pos.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/dna
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example/solubility
# copying build/lib/PyBioMed/example/solubility/Solubility-total.xlsx -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/solubility
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example/caco2
# copying build/lib/PyBioMed/example/caco2/caco2.xlsx -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/caco2
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/example/subcell
# copying build/lib/PyBioMed/example/subcell/Cytoplasm_seq.txt -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/subcell
# copying build/lib/PyBioMed/example/subcell/Nuclear_seq.txt -> /usr/local/lib/python3.6/site-packages/PyBioMed/example/subcell
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1f88.ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1f88.ent(1).gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1atp (1).pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/download.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1f88 (1).ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/overview.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/modules(1).rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/application.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/User_guide.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1atp.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1atp(1).pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/Makefile -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/application(1).rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/modules (1).rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/Descriptor/Documentation.pdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/Descriptor/PyBioMed Chem.pdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/Descriptor/PyBioMed Protein.pdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/Descriptor/PyBioMed DNA.pdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/Descriptor/PyBioMed Interaction.pdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc/Descriptor
# copying build/lib/PyBioMed/doc/application (1).rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/conf.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/index.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/test.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/modules.rst -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/make.bat -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1f88.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/doc/1efz.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/doc
# copying build/lib/PyBioMed/Pyprotein.py -> /usr/local/lib/python3.6/site-packages/PyBioMed
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyProtein.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyBioMed.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/neg.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/hs.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/drug.sdf -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/protein.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/example.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/pos.fasta -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/drug.smi -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/drug.mol -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/target.txt -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/drug.inchi -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_data/test.mol -> /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_data
# copying build/lib/PyBioMed/test/test_PyPretreat.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/1atp.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyInteration.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/1atp.ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyDNA.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyMolecule.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/test_PyGetMol.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/1f88.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/test/1efz.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/test
# copying build/lib/PyBioMed/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1f88.ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1atp.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/GetDNA.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/Getmol.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1atp.ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/GetProtein.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1efz.ent.gz -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1f88.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# copying build/lib/PyBioMed/PyGetMol/1efz.pdb -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyInteraction
# copying build/lib/PyBioMed/PyInteraction/PyInteraction.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyInteraction
# copying build/lib/PyBioMed/PyInteraction/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyInteraction
# creating /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/topology.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/basak.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/Scaffolds.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/connectivity.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/bcut.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/kappa.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/cats2d.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/AtomProperty.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/moe.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/MinimalFeatures.fdef -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/molproperty.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/__init__.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/PubChemFingerprints.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/charge.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/AtomTypes.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/ghosecrippen.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/estate.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/geary.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/fingerprint.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/moreaubroto.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/Crippen.txt -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/constitution.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# copying build/lib/PyBioMed/PyMolecule/moran.py -> /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNA (1).py to PyDNA (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAutil (1).py to PyDNAutil (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAacutil.py to PyDNAacutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAnacutil.py to PyDNAnacutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNApsenac(1).py to PyDNApsenac(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNApsenacutil.py to PyDNApsenacutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNApsenac (1).py to PyDNApsenac (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNA.py to PyDNA.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAac.py to PyDNAac.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAutil.py to PyDNAutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAac (1).py to PyDNAac (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAnac.py to PyDNAnac.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAnacutil (1).py to PyDNAnacutil (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/__init__ (1).py to __init__ (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAac(1).py to PyDNAac(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAutil(1).py to PyDNAutil(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNAnacutil(1).py to PyDNAnacutil(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNApsenac.py to PyDNApsenac.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/__init__(1).py to __init__(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyDNA/PyDNA(1).py to PyDNA(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/Pymolecule.py to Pymolecule.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/Pyinteraction.py to Pyinteraction.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/Pydna.py to Pydna.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPretreatMolutil.py to PyPretreatMolutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPretreatPro.py to PyPretreatPro.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyDNAutil.py to PyDNAutil.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPretreatDNA.py to PyPretreatDNA.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPreTools (1).py to PyPreTools (1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPreTools(1).py to PyPreTools(1).cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPretreatMol.py to PyPretreatMol.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyPretreat/PyPreTools.py to PyPreTools.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/PyProteinAAComposition.py to PyProteinAAComposition.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/ConjointTriad.py to ConjointTriad.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/GetProteinFromUniprot.py to GetProteinFromUniprot.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/PyProteinAAIndex.py to PyProteinAAIndex.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/PseudoAAC.py to PseudoAAC.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/QuasiSequenceOrder.py to QuasiSequenceOrder.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/AAComposition.py to AAComposition.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/ProCheck.py to ProCheck.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/GetSubSeq.py to GetSubSeq.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/Autocorrelation.py to Autocorrelation.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/CTD.py to CTD.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/AAIndex.py to AAIndex.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyProtein/PyProtein.py to PyProtein.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/doc/conf.py to conf.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/Pyprotein.py to Pyprotein.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test.py to test.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyProtein.py to test_PyProtein.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyBioMed.py to test_PyBioMed.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyPretreat.py to test_PyPretreat.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyInteration.py to test_PyInteration.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyDNA.py to test_PyDNA.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyMolecule.py to test_PyMolecule.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/test/test_PyGetMol.py to test_PyGetMol.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol/GetDNA.py to GetDNA.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol/Getmol.py to Getmol.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyGetMol/GetProtein.py to GetProtein.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyInteraction/PyInteraction.py to PyInteraction.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyInteraction/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/topology.py to topology.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/basak.py to basak.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/Scaffolds.py to Scaffolds.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/connectivity.py to connectivity.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/bcut.py to bcut.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/kappa.py to kappa.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/cats2d.py to cats2d.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/AtomProperty.py to AtomProperty.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/moe.py to moe.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/molproperty.py to molproperty.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/PubChemFingerprints.py to PubChemFingerprints.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/charge.py to charge.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/AtomTypes.py to AtomTypes.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/ghosecrippen.py to ghosecrippen.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/estate.py to estate.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/geary.py to geary.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/fingerprint.py to fingerprint.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/moreaubroto.py to moreaubroto.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/constitution.py to constitution.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/site-packages/PyBioMed/PyMolecule/moran.py to moran.cpython-36.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.6/site-packages/PyBioMed-1.0-py3.6.egg-info
# /content

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/My Drive/PyBioMed-1.0
# %pwd
# !python3 setup.py install
# %cd ..

# %% [markdown]
# Now you must **Restart the** **Runtime**

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from google.colab import drive
from google.colab import files
import os
from rdkit import Chem
from Bio import SeqIO
from PyBioMed.PyProtein import AAComposition
from PyBioMed.PyProtein import CTD
from PyBioMed.PyProtein import ConjointTriad,Autocorrelation
from mordred import Calculator,descriptors,Weight
import tqdm
import random
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import random
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from mordred import Calculator,descriptors,Weight
from tqdm import tqdm
import time
import pennylane as qml
from pennylane import numpy as np
import pennylane.optimize
import os
import time
import random
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchsummary import summary
import torchvision.datasets as dset
import torchvision.transforms as transforms
import math
from qiskit import BasicAer
from qiskit.aqua.algorithms import QSVM
from qiskit.aqua import run_algorithm, QuantumInstance
from qiskit.aqua.components.feature_maps import SecondOrderExpansion
from qiskit import IBMQ
import scipy
from scipy.linalg import expm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Data Download and Preprocessing

# %% [markdown]
# ### dataPrep():
#     This function can be used to generate the molecular descriptors from the drugBank dataset and store them as CSV files, which are later accessed by the preprocess function. The csv files used in the dataPrep function were obtained from the drugbank dataset. New csv files will be saved in the environment which will be used in the preprocess() function.
#
# ### preprocess():
#     This function forms the training and test dataset from the csv files saved using the dataPrep() function.
#
# It is not required to run the dataPrep() function as we have already provided the csv files with the descriptors calulated.

# %%
config = {
    'records': 100,
    'qbits': 10
}
def getProteinDescriptor(protSeq):
    res = {}
    res.update(AAComposition.CalculateAAComposition(protSeq))
    res.update(AAComposition.CalculateDipeptideComposition(protSeq))
    res.update(Autocorrelation.CalculateNormalizedMoreauBrotoAutoTotal(protSeq))
    res.update(Autocorrelation.CalculateMoranAutoTotal(protSeq))
    res.update(ConjointTriad.CalculateConjointTriad(protSeq))
    return res

def preprocess():
    proteinDescriptorsDF = pd.read_csv('/content/protein_descriptor.csv')
    drugTargetPair_positive = pd.read_csv('/content/positive_pair.csv')
    drugTargetPair_negative = pd.read_csv('/content/negative_pair.csv')
    drugList_positive = drugTargetPair_positive['Drug'].tolist()
    targetList_positive = drugTargetPair_positive['Target'].tolist()

    drugList_negative = drugTargetPair_negative['Drug'].tolist()
    targetList_negative = drugTargetPair_negative['Target'].tolist()

    drugDescriptors = pd.read_csv('/content/molecule_descriptor_new.csv')

    drugDescriptorsNumeric = drugDescriptors.apply(pd.to_numeric,errors='coerce')
    drugDescriptorsNumeric = drugDescriptorsNumeric.dropna(axis = 1)
    proteinDescriptorsDFNumeric = proteinDescriptorsDF.apply(pd.to_numeric,errors='coerce')
    proteinDescriptorsDFNumeric = proteinDescriptorsDFNumeric.dropna(axis=1)

    drugDescriptorID = drugDescriptors['ID'].tolist()

    finalDrugTargetPair_positive = []
    targetDescriptorID = proteinDescriptorsDF['Protein ID'].tolist()
    Y_positive = []
    for i in tqdm(range(len(targetList_positive))):
        targetID = targetList_positive[i]
        drugID = drugList_positive[i]
        if targetID in targetDescriptorID and drugID in drugDescriptorID:
            indexTarget = targetDescriptorID.index(targetID)
            indexDrug = drugDescriptorID.index(drugID)
            proteinDescriptorsArray = proteinDescriptorsDFNumeric.iloc[indexTarget].to_numpy().astype(np.float)
            drugDescriptorArray = drugDescriptorsNumeric.iloc[indexDrug].to_numpy().astype(np.float)
            pairDescriptor = np.concatenate([proteinDescriptorsArray,drugDescriptorArray])
            finalDrugTargetPair_positive.append(([drugID,targetID],pairDescriptor))
        else:
            continue
    print(len(finalDrugTargetPair_positive))
    print(len(finalDrugTargetPair_positive[0][1]))

    # Cell number 2

    Y_positive = [1] * len(finalDrugTargetPair_positive)

    finalDrugTargetPair_negative = []
    for i in tqdm(range(len(targetList_positive))):
        targetID = targetList_negative[i]
        drugID = drugList_negative[i]
        if targetID in targetDescriptorID and drugID in drugDescriptorID:
            indexTarget = targetDescriptorID.index(targetID)
            indexDrug = drugDescriptorID.index(drugID)
            proteinDescriptorsArray = proteinDescriptorsDFNumeric.iloc[indexTarget].to_numpy().astype(np.float)
            drugDescriptorArray = drugDescriptorsNumeric.iloc[indexDrug].to_numpy().astype(np.float)
            pairDescriptor = np.concatenate([proteinDescriptorsArray,drugDescriptorArray])
            finalDrugTargetPair_negative.append(([drugID,targetID],pairDescriptor))
        else:
            continue
    Y_negative = [0] * len(finalDrugTargetPair_negative)

    #Cell number 3

    X = np.empty((len(finalDrugTargetPair_positive)+len(finalDrugTargetPair_negative),len(finalDrugTargetPair_positive[0][1])))
    count = 0
    for info in finalDrugTargetPair_positive:
        X[count] = info[1]
        count += 1
    for info in finalDrugTargetPair_negative:
        X[count] = info[1]
        count += 1
    Y = Y_positive + Y_negative

    #Cell number 4

    import random
    from sklearn.model_selection import train_test_split
    temp = []
    for i in range(len(X)):
        temp.append([X[i],Y[i]])
    random.shuffle(temp)
    for i in range(len(temp)):
        X[i] = temp[i][0]
        Y[i] = temp[i][1]
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)
    standardScalerObject = StandardScaler().fit(X_train)
    sample_train = standardScalerObject.transform(X_train)
    sample_test = standardScalerObject.transform(X_test)

    pca = PCA(n_components=config['qbits']).fit(sample_train)
    sample_train = pca.transform(sample_train)
    sample_test = pca.transform(sample_test)
    samples = np.append(sample_train,sample_test,axis=0)
    minmax_scale = MinMaxScaler((-1,1)).fit(samples)
    sample_train = minmax_scale.transform(sample_train)
    sample_test = minmax_scale.transform(sample_test)
    class_labels = [1,0]
    label_train, label_test = y_train, y_test
    training_size = len(y_train)
    test_size = len(y_test)
    sample_train_positive = np.empty((len(finalDrugTargetPair_positive),config['qbits']))
    sample_train_negative = np.empty((len(finalDrugTargetPair_negative),config['qbits']))
    count_pos,count_neg = 0,0
    for i in range(len(y_train)):
        if y_train[i] == 1:
            sample_train_positive[count_pos] = sample_train[i]
            count_pos += 1
        else:
            sample_train_negative[count_neg] = sample_train[i]
            count_neg += 1
    sample_test_positive = np.empty((len(finalDrugTargetPair_positive),config['qbits']))
    sample_test_negative = np.empty((len(finalDrugTargetPair_negative),config['qbits']))
    count_pos,count_neg = 0,0        
    for i in range(len(y_test)):
        if y_test[i] == 1:
            sample_test_positive[count_pos] = sample_train[i]
            count_pos += 1
        else:
            sample_test_negative[count_neg] = sample_train[i]
            count_neg += 1
    print(sample_train_positive.shape) 
    print(sample_train_negative.shape)
    print(sample_test_negative.shape)
    print(sample_test_positive.shape)
    training_input = {1:sample_train_positive,0:sample_train_negative}
    test_input = {1:sample_test_positive,0:sample_test_negative}
    sample_train = np.concatenate((sample_train_negative,sample_train_positive),axis=0)
    sample_y_train = np.concatenate((np.zeros((sample_train_negative.shape[0],)),np.ones((sample_train_positive.shape[0],))),axis=0)
    print(sample_train.shape)
    print(sample_y_train.shape)
    import random
    from sklearn.model_selection import train_test_split
    temp = []
    for i in range(len(X)):
        temp.append([sample_train[i],sample_y_train[i]])
    random.shuffle(temp)
    for i in range(len(temp)):
        sample_train[i] = temp[i][0]
        sample_y_train[i] = temp[i][1]
    print(sample_train.shape)
    print(sample_y_train.shape)
    sample_test = np.concatenate((sample_test_negative,sample_test_positive),axis=0)
    sample_y_test = np.concatenate((np.zeros((sample_test_negative.shape[0],)),np.ones((sample_test_positive.shape[0],))),axis=0)
    print(sample_test.shape)
    print(sample_y_test.shape)
    import random
    from sklearn.model_selection import train_test_split
    temp = []
    for i in range(len(X)):
        temp.append([sample_test[i],sample_y_test[i]])
    random.shuffle(temp)
    for i in range(len(temp)):
        sample_test[i] = temp[i][0]
        sample_y_test[i] = temp[i][1]
    print(sample_test.shape)
    print(sample_y_test.shape)

    import math
    for i in training_input:
        for j,_ in enumerate(training_input[i]):
            for k,_ in enumerate(training_input[i][j]):
                if math.isnan(training_input[i][j][k]):
                    training_input[i][j][k] = 0
    for i in test_input:
        for j,_ in enumerate(test_input[i]):
            for k,_ in enumerate(test_input[i][j]):
                if math.isnan(test_input[i][j][k]):
                    test_input[i][j][k] = 0

    for i in training_input:
        training_input[i] = training_input[i][:config['records']]
    for i in test_input:
        test_input[i] = test_input[i][:config['records']]
    X_train = []
    y_train = []
    for i in training_input:
        for j in training_input[i]:
            X_train.append(j)
            y_train.append(i)
    c = list(zip(X_train, y_train))
    random.shuffle(c)
    X_train, y_train = zip(*c)

    X_test = []
    y_test = []
    for i in test_input:
        for j in test_input[i]:
            X_test.append(j)
            y_test.append(i)
    c = list(zip(X_test, y_test))
    random.shuffle(c)
    X_test, y_test = zip(*c)
    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    print(training_input)
    print(test_input)
    return X_train,X_test,y_train,y_test,training_input,test_input

def dataPrep():
    target = pd.read_csv("/content/drive/My Drive/all.csv")
    drugs = pd.read_csv("/content/drive/My Drive/drug_links.csv")
    structures = pd.read_csv("/content/drive/My Drive/structure_links.csv")
    structures = structures[['DrugBank ID','Name','SMILES']]
    structures = structures.dropna()
    smilesList = structures['SMILES'].tolist()
    idList = structures['DrugBank ID'].tolist()
    drugsInteracting = target['Drug IDs'].tolist()
    drugsSet = set()
    for i in drugsInteracting:
        lsTemp = i.split('; ')
        for drugId in lsTemp:
            drugsSet.add(drugId)
    drugsInteracting = list(drugsSet)
    structures = structures[structures['DrugBank ID'].isin(drugsInteracting)]
    smilesList = structures['SMILES'].tolist()
    idList = structures['DrugBank ID'].tolist()
    calc = Calculator(descriptors, ignore_3D=True)
    descriptorMolecule = {}
    discardCount = 0
    newMoleculeList, newDescriptorList = [],[]
    molList = []
    for i in range(len(molList)):
        tempDescriptorContainer = calc(molList[i])
        if len(tempDescriptorContainer) == 1613:
            newDescriptorList.append(tempDescriptorContainer)
            newMoleculeList.append(molList[i])
        else:
            discardCount += 1
    moleculesListDF = pd.DataFrame(newDescriptorList)
    moleculesListDF.insert(0,'Molecules',molList)
    moleculesListDF.insert(0,'ID',structures['DrugBank ID'].tolist())
    export_csv = moleculesListDF.to_csv(r'/content/drive/My Drive/molecule_descriptor_full_dataset.csv',index = None, header=True)
    descriptorsCSV = pd.read_csv("/content/drive/My Drive/molecule_descriptor_full_dataset.csv")
    drugsInDescriptors = descriptorsCSV['ID'].tolist()
    data = []
    proteinDescriptors = []
    proteinList = []
    drugTargetPair = {}
    for seq_record in SeqIO.parse("/content/drive/My Drive/protein.fasta", "fasta"):
        targetDrug = seq_record.description
        sequenceProtein = str(seq_record.seq)
        proteinID = str(seq_record.id).split('|')[1]
        targetDrugs = targetDrug[targetDrug.find("(")+1:targetDrug.find(")")]
        targetDrugs = targetDrugs.split("; ")
        data.append([sequenceProtein,(proteinID,targetDrugs)])
    drug_pair_negative = []
    drug_pair_positive = []
    drugDecoyStr_negative = []
    drugDecoyStr_positive = []
    for item in data:
        decoyID = item[1][0]
        drugsList = item[1][1]
        for drug in drugsInDescriptors:
            if drug not in drugsList:
                drug_pair_negative.append([drug,decoyID])
                drugDecoyStr_negative.append(drug+decoyID)
            else:
                drug_pair_positive.append([drug,decoyID])
                drugDecoyStr_positive.append(drug+decoyID)
    random.shuffle(drug_pair_negative)
    random.shuffle(drug_pair_positive)
    drug_pair_negative_dataframe = pd.DataFrame(drug_pair_negative)
    drug_pair_positive_dataframe = pd.DataFrame(drug_pair_positive)
    drug_pair_negative_dataframe = drug_pair_negative_dataframe.rename(columns={0: "Drug", 1: "Target"})
    drug_pair_positive_dataframe = drug_pair_positive_dataframe.rename(columns={0: "Drug", 1: "Target"})
    exported_drug_pair_negative = drug_pair_positive_dataframe.to_csv(r'/content/drive/My Drive/positive_pair.csv',index = None, header=True)
    exported_drug_pair_positive = drug_pair_negative_dataframe.to_csv(r'/content/drive/My Drive/negative_pair.csv',index = None, header=True)
    drugTargetList = []
    proteinDescriptors = []
    for i in range(len(data)):
        mergedData = data[i]
        proteinSequence = mergedData[0]
        proteinId = mergedData[1][0]
        drugs = mergedData[1][1]
    #     print(i)        
        try:
            proteinDescriptors.append([proteinId,getProteinDescriptor(proteinSequence)])
        except:
            print("Exception Occured for proteinID {}".format(proteinId))
    descriptorsList = []        
    proteinIDList = []
    for descriptor in proteinDescriptors:
        descriptorsList.append(descriptor[1])
        proteinIDList.append(descriptor[0])
    proteinDescriptorsDF = pd.DataFrame(descriptorsList)
    proteinDescriptorsDF.insert(0,"Protein ID",proteinIDList)
    export_csv = proteinDescriptorsDF.to_csv('/content/drive/My Drive/protein_descriptor_decoy.csv',index = None, header=True)

# %%
# dataPrep()
X_train,X_test,y_train,y_test,training_input,test_input = preprocess()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (54,55,56,57,58,59,60,61,62,90,91,92,93,94,95,96,97,98,108,109,110,111,112,113,114,115,116,136,137,145,146,153,154,155,163,164,172,173,181,182,189,190,191,199,200,207,208,209,217,218,226,227,261,262,263,264,265,266,267,268,269,297,298,299,300,301,302,303,304,305,315,316,317,318,319,320,321,322,323,352,353,361,362,369,370,371,379,380,388,389,397,398,405,406,407,415,416,423,424,425,433,434,442,443,458,459,466,467,474,475,482,483,490,491,498,499,506,507,514,515,522,523,530,531,538,539,554,555,562,563,570,571,578,579,586,587,594,595,602,603,610,611,618,619,626,627,634,635,808,818,826,827,828,834,835,836,842,843,844,853,855,861,863,1270,1271,1272,1273,1274,1275,1276,1277,1278,1279,1280,1281,1300,1301,1303,1304,1553,1581,1582,1584,1612) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# 100%|██████████| 9144/9144 [00:11<00:00, 770.03it/s]
#   1%|          | 92/9144 [00:00<00:09, 906.91it/s]
# 6669
# 1821
# 100%|██████████| 9144/9144 [00:10<00:00, 876.30it/s]
# (6669, 10)
# (5387, 10)
# (5387, 10)
# (6669, 10)
# (12056, 10)
# (12056,)
# (12056, 10)
# (12056,)
# (12056, 10)
# (12056,)
# (12056, 10)
# (12056,)
# {1: array([[-0.59736586, -0.84287605, -0.21604904, -0.37968079, -0.17532904,
#         -0.46774585, -0.61702309, -0.54803341, -0.11118806, -0.29614966],
#        [-0.49652731, -0.88480255, -0.2380466 , -0.49388601,  0.006806  ,
#         -0.42797704, -0.57089429, -0.50289106, -0.01213286, -0.2382022 ],
#        [-0.3472722 , -0.88047998, -0.30654392, -0.58606654,  0.0288498 ,
#         -0.40931132, -0.51758397, -0.59252132, -0.09532696, -0.2077864 ],
#         -3.92057176e-01, -9.20210849e-02, -5.83352209e-01,
#         -6.36455001e-01, -5.19696042e-01, -1.55874566e-01,
#         -2.48910348e-01],
#        [-3.51658867e-01, -8.73143258e-01, -6.06293016e-02,
#         -4.01340971e-01, -2.44667003e-01, -5.04821432e-01,
#         -6.32530803e-01, -5.41202023e-01, -1.15156975e-01,
#         -2.36742021e-01],
#        [-4.15527088e-01, -8.64456874e-01, -2.63232268e-01,
#         -4.29454312e-01, -1.45661710e-01, -4.99269710e-01,
#         -6.71869478e-01, -5.10008878e-01, -1.43993902e-01,
#         -2.75218196e-01]])}

# %% [markdown]
# ## Classical SVM

# %%
svcClassifier = SVC(gamma = 'auto')
svcClassifier.fit(X_train,y_train)
print(svcClassifier.score(X_test,y_test))
# Out:
# 0.5

# %% [markdown]
# ## Classical DNN

# %%
n = config['qbits']
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024,activation='relu',input_shape=(n,)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
result = model.fit(X_train,y_train,batch_size=32,epochs=100)
model.evaluate(X_test,y_test)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 200/200 [==============================] - 1s 3ms/sample - loss: 0.6995 - acc: 0.5000
# Epoch 2/100
# 200/200 [==============================] - 0s 527us/sample - loss: 0.6938 - acc: 0.4850
# Epoch 3/100
# 200/200 [==============================] - 0s 568us/sample - loss: 0.7016 - acc: 0.5000
# Epoch 4/100
# 200/200 [==============================] - 0s 512us/sample - loss: 0.6951 - acc: 0.4600
# Epoch 5/100
# 200/200 [==============================] - 0s 513us/sample - loss: 0.6933 - acc: 0.5000
# Epoch 6/100
# 200/200 [==============================] - 0s 509us/sample - loss: 0.6934 - acc: 0.4850
# Epoch 7/100
# 200/200 [==============================] - 0s 498us/sample - loss: 0.6923 - acc: 0.5400
# Epoch 8/100
# 200/200 [==============================] - 0s 513us/sample - loss: 0.6912 - acc: 0.5550
# Epoch 9/100
# 200/200 [==============================] - 0s 518us/sample - loss: 0.6894 - acc: 0.5150
# Epoch 10/100
# 200/200 [==============================] - 0s 500us/sample - loss: 0.6921 - acc: 0.4550
# Epoch 11/100
# 200/200 [==============================] - 0s 493us/sample - loss: 0.6892 - acc: 0.5250
# Epoch 12/100
# 200/200 [==============================] - 0s 525us/sample - loss: 0.6999 - acc: 0.5200
# Epoch 13/100
# 200/200 [==============================] - 0s 567us/sample - loss: 0.6857 - acc: 0.5550
# Epoch 14/100
# 200/200 [==============================] - 0s 490us/sample - loss: 0.6919 - acc: 0.5200
# Epoch 15/100
# 200/200 [==============================] - 0s 527us/sample - loss: 0.6868 - acc: 0.5300
# Epoch 16/100
# 200/200 [==============================] - 0s 488us/sample - loss: 0.6835 - acc: 0.5300
# Epoch 17/100
# 200/200 [==============================] - 0s 495us/sample - loss: 0.6790 - acc: 0.5550
# Epoch 18/100
# 200/200 [==============================] - 0s 538us/sample - loss: 0.6234 - acc: 0.6400
# Epoch 79/100
# 200/200 [==============================] - 0s 536us/sample - loss: 0.6114 - acc: 0.6300
# Epoch 80/100
# 200/200 [==============================] - 0s 485us/sample - loss: 0.6091 - acc: 0.6400
# Epoch 81/100
# 200/200 [==============================] - 0s 526us/sample - loss: 0.6317 - acc: 0.6200
# Epoch 82/100
# 200/200 [==============================] - 0s 581us/sample - loss: 0.6187 - acc: 0.6050
# Epoch 83/100
# 200/200 [==============================] - 0s 485us/sample - loss: 0.6264 - acc: 0.6200
# Epoch 84/100
# 200/200 [==============================] - 0s 540us/sample - loss: 0.6017 - acc: 0.6400
# Epoch 85/100
# 200/200 [==============================] - 0s 517us/sample - loss: 0.6041 - acc: 0.6250
# Epoch 86/100
# 200/200 [==============================] - 0s 520us/sample - loss: 0.6244 - acc: 0.6350
# Epoch 87/100
# 200/200 [==============================] - 0s 519us/sample - loss: 0.6113 - acc: 0.6400
# Epoch 88/100
# 200/200 [==============================] - 0s 498us/sample - loss: 0.6055 - acc: 0.6150
# Epoch 89/100
# 200/200 [==============================] - 0s 501us/sample - loss: 0.5939 - acc: 0.6400
# Epoch 90/100
# 200/200 [==============================] - 0s 495us/sample - loss: 0.5718 - acc: 0.6500
# Epoch 91/100
# 200/200 [==============================] - 0s 563us/sample - loss: 0.5738 - acc: 0.6400
# Epoch 92/100
# 200/200 [==============================] - 0s 509us/sample - loss: 0.5748 - acc: 0.6550
# Epoch 93/100
# 200/200 [==============================] - 0s 484us/sample - loss: 0.5713 - acc: 0.6400
# Epoch 94/100
# 200/200 [==============================] - 0s 553us/sample - loss: 0.5758 - acc: 0.6300
# Epoch 95/100
# 200/200 [==============================] - 0s 490us/sample - loss: 0.5583 - acc: 0.6750
# Epoch 96/100
# 200/200 [==============================] - 0s 505us/sample - loss: 0.5952 - acc: 0.6600
# Epoch 97/100
# 200/200 [==============================] - 0s 515us/sample - loss: 0.6482 - acc: 0.6200
# Epoch 98/100
# 200/200 [==============================] - 0s 488us/sample - loss: 0.6002 - acc: 0.6250
# Epoch 99/100
# 200/200 [==============================] - 0s 526us/sample - loss: 0.6508 - acc: 0.6100
# Epoch 100/100
# 200/200 [==============================] - 0s 516us/sample - loss: 0.6739 - acc: 0.6050
# 200/200 [==============================] - 0s 237us/sample - loss: 0.9906 - acc: 0.5100
# [0.9905993366241455, 0.51]

# %% [markdown]
# ## Quantum SVM

# %% [markdown]
# Here we are using the qiskit library by IBM which can be used to run quantum algorithms on IBM's quantum computers or quantum simulators. We chose to use qiskit because of aqua, a sub-library of the qiskit framework. Aqua has some pre-implemented quantum algorithms such as QSVM which makes it easy to run and try the algorithm for people who are currently exploring the domain of quantum computing.
#
# It may take time to run the Quantum SVM using the code below. This may be because of long queues for accessing the servers and running your request on the server.
#
# ***Remember to store your IBMQ account token in the variable "IBM_TOKEN".***

# %%
# To enable on publication
# IBM_TOKEN = 'YOUR_TOKEN'


config_IBMQ = {
    'hub': 'ibm-q',
    'group': 'open',
    'project': 'main',
    'entanglement': 'full',
    'token': IBM_TOKEN,
    'server': 'qasm_simulator',
    #'server': 'ibmq_qasm_simulator',
    #'server': 'ibmq_16_melbourne',
    'shots': 512,
    'depth': 2,
    'seed': 10598,
    'local': True,
    #'local': False,
    'qbits': 10,
    'records': 20
}

IBMQ.save_account(config_IBMQ['token'])
if config_IBMQ['local']:
  #IBMQ.load_accounts(hub=None)
  feature_map = SecondOrderExpansion(feature_dimension=config['qbits'], depth=config_IBMQ['depth'], entanglement=config_IBMQ['entanglement'])
  qsvm = QSVM(feature_map, training_input, test_input)
  backend = BasicAer.get_backend(config_IBMQ['server'])
  quantum_instance = QuantumInstance(backend, shots=config_IBMQ['shots'], seed_transpiler=config_IBMQ['seed'])
  result = qsvm.run(quantum_instance)
  print(result)
else:
  IBMQ.load_accounts(hub=None)
  feature_map = SecondOrderExpansion(feature_dimension=config_IBMQ['qbits'], depth=config_IBMQ['depth'], entanglement=config_IBMQ['entanglement'])
  qsvm = QSVM(feature_map, training_input, test_input)
  provider = IBMQ.get_provider()
  backend = provider.get_backend(config_IBMQ['server'])
  quantum_instance = QuantumInstance(backend, shots=config_IBMQ['shots'], seed_transpiler=config_IBMQ['seed'], skip_qobj_validation=False)
  result = qsvm.run(quantum_instance)
  print(result)

# %% [markdown]
# ## Quantum Neural Networks

# %%
import pickle
pickle.dump(X_train, open('X_train.pkl','wb'))
pickle.dump(y_train, open('y_train.pkl','wb'))

# %%
# %%time
# !git clone https://github.com/kkhosla96/QuantumImageClassification.git
# !mv -f QuantumImageClassification/* .
# !wget -O forest.tar.bz2 https://u8193507.ct.sendgrid.net/wf/click?upn=DVKTQCcBwH4CT-2FFvSWVL6I8GFSrqY0JvhZilrlFpk6lSWAqkKzSQZCfsqrBpen2137Fh1pWiF-2BeEq6eQOu9jPPGlL-2F0pZyLc4a9q2CpBuGQ-3D_L-2BfbHitP5D1pgZUrqcep5r44S8QKIpb03x-2Fd-2FtOrEiFZuJLLF0oXQyHcAAbvtcugKWy-2BlR4Kzqro3bSbn3SX1pbw86WGJCkYpnwepwXT-2BBsER4n0lqBTp-2FbCVK2VFLz1HAHsucc-2Be5Kb6-2Btt7BCFtccUQEkxCVAsR2gpMpGRxfkCTS6pntYaFEa9PTw4ZIsjBxJLM0eevDPZnIMydBiHP-2F7q-2BMti-2BTNGeGx7TfVbWwer-2FlFFdl0PQG0PM1lEooq7IxmDzNDAA1Yu6rd2qlqTWEkG-2BXejYm0jAOHOvj6n1XQC-2F6VpQjxO7An7tL-2BgM2vMLEgitquZjgqBZ5s2GaZ-2FH4RTzlk9gA02fg-2Bd-2FGo-2FiFZ812yd-2FBGuRRQBgiGQu71u2w-2FsQrKlhuQiXi-2B-2BsamcPeXY1yxPzmhz8LG4iYogCQA-3D
# !tar -xvf forest.tar.bz2
# Out:
# Cloning into 'QuantumImageClassification'...
# remote: Enumerating objects: 130, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 130 (delta 48), reused 97 (delta 21), pack-reused 0
# Receiving objects: 100% (130/130), 4.25 MiB | 12.23 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# --2019-09-13 12:51:22--  https://u8193507.ct.sendgrid.net/wf/click?upn=DVKTQCcBwH4CT-2FFvSWVL6I8GFSrqY0JvhZilrlFpk6lSWAqkKzSQZCfsqrBpen2137Fh1pWiF-2BeEq6eQOu9jPPGlL-2F0pZyLc4a9q2CpBuGQ-3D_L-2BfbHitP5D1pgZUrqcep5r44S8QKIpb03x-2Fd-2FtOrEiFZuJLLF0oXQyHcAAbvtcugKWy-2BlR4Kzqro3bSbn3SX1pbw86WGJCkYpnwepwXT-2BBsER4n0lqBTp-2FbCVK2VFLz1HAHsucc-2Be5Kb6-2Btt7BCFtccUQEkxCVAsR2gpMpGRxfkCTS6pntYaFEa9PTw4ZIsjBxJLM0eevDPZnIMydBiHP-2F7q-2BMti-2BTNGeGx7TfVbWwer-2FlFFdl0PQG0PM1lEooq7IxmDzNDAA1Yu6rd2qlqTWEkG-2BXejYm0jAOHOvj6n1XQC-2F6VpQjxO7An7tL-2BgM2vMLEgitquZjgqBZ5s2GaZ-2FH4RTzlk9gA02fg-2Bd-2FGo-2FiFZ812yd-2FBGuRRQBgiGQu71u2w-2FsQrKlhuQiXi-2B-2BsamcPeXY1yxPzmhz8LG4iYogCQA-3D
# Resolving u8193507.ct.sendgrid.net (u8193507.ct.sendgrid.net)... 167.89.123.16, 167.89.118.35
# Connecting to u8193507.ct.sendgrid.net (u8193507.ct.sendgrid.net)|167.89.123.16|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloads.rigetti.com/qcs-sdk/forest-sdk-linux-deb.tar.bz2 [following]
# --2019-09-13 12:51:22--  https://downloads.rigetti.com/qcs-sdk/forest-sdk-linux-deb.tar.bz2
# Resolving downloads.rigetti.com (downloads.rigetti.com)... 13.224.29.29, 13.224.29.15, 13.224.29.70, ...
# Connecting to downloads.rigetti.com (downloads.rigetti.com)|13.224.29.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54161549 (52M) [application/x-bzip2]
# Saving to: ‘forest.tar.bz2’
#
# forest.tar.bz2      100%[===================>]  51.65M  79.4MB/s    in 0.7s
#
# 2019-09-13 12:51:23 (79.4 MB/s) - ‘forest.tar.bz2’ saved [54161549/54161549]
#
# forest-sdk-2.11.0-linux-deb/
# forest-sdk-2.11.0-linux-deb/forest-sdk-2.11.0-linux-deb.run
# forest-sdk-2.11.0-linux-deb/README.txt
# /bin/bash: /content/forest-sdk-2.8.0-linux-deb/forest-sdk-2.8.0-linux-deb.run: No such file or directory
# Collecting pyquil
#   Downloading https://files.pythonhosted.org/packages/9b/65/40d512a067ce1ec4278d6735518438f88ef4b22a21e0cacc73febd1b49a3/pyquil-2.11.0.tar.gz (173kB)
#      |████████████████████████████████| 174kB 5.0MB/s
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.6/site-packages (from pyquil) (1.17.2)
# Collecting antlr4-python3-runtime (from pyquil)
#   Downloading https://files.pythonhosted.org/packages/29/14/8ac135ec7cc9db3f768e2d032776718c6b23f74e63543f0974b4873500b2/antlr4-python3-runtime-4.7.2.tar.gz (112kB)
#      |████████████████████████████████| 112kB 49.4MB/s
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/site-packages (from pyquil) (2.22.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/site-packages (from pyquil) (1.11.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0.0 in /usr/local/lib/python3.6/site-packages (from pyquil) (2.3)
# Collecting rpcq>=2.7.2 (from pyquil)
#   Downloading https://files.pythonhosted.org/packages/52/d8/62f38429b2ffd19c09a67271dfacf1a112e8ff73774e9a64453ed8c10110/rpcq-2.7.3.tar.gz
# Collecting immutables==0.6 (from pyquil)
#   Downloading https://files.pythonhosted.org/packages/93/85/14400a6cadf89d9cb369b3b7013baa766ea2a9fabe50d7a711ed8a6cc5d9/immutables-0.6-cp36-cp36m-manylinux1_x86_64.whl (70kB)
#      |████████████████████████████████| 71kB 25.4MB/s
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests->pyquil) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests->pyquil) (1.22)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests->pyquil) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests->pyquil) (2019.6.16)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx>=2.0.0->pyquil) (4.4.0)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil) (0.17.1)
# Collecting msgpack>=0.6 (from rpcq>=2.7.2->pyquil)
#   Downloading https://files.pythonhosted.org/packages/92/7e/ae9e91c1bb8d846efafd1f353476e3fd7309778b582d2fb4cea4cc15b9a2/msgpack-0.6.1-cp36-cp36m-manylinux1_x86_64.whl (248kB)
#      |████████████████████████████████| 256kB 46.4MB/s
# Collecting python-rapidjson (from rpcq>=2.7.2->pyquil)
#   Downloading https://files.pythonhosted.org/packages/dd/32/7da92d409426dde28cdf844e7b1df1f8a5a790e0d53b45b850641946ddd6/python_rapidjson-0.8.0-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 46.3MB/s
# Collecting pyzmq>=17 (from rpcq>=2.7.2->pyquil)
#   Downloading https://files.pythonhosted.org/packages/75/89/6f0ea51ffa9c2c00c0ab0460f137b16a5ab5b47e3b060c5b1fc9ca425836/pyzmq-18.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 41.7MB/s
# Collecting ruamel.yaml (from rpcq>=2.7.2->pyquil)
#   Downloading https://files.pythonhosted.org/packages/fa/90/ecff85a2e9c497e2fa7142496e10233556b5137db5bd46f3f3b006935ca8/ruamel.yaml-0.16.5-py2.py3-none-any.whl (123kB)
#      |████████████████████████████████| 133kB 46.8MB/s
# Requirement already satisfied, skipping upgrade: typing in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil) (3.6.2)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" (from ruamel.yaml->rpcq>=2.7.2->pyquil)
#   Downloading https://files.pythonhosted.org/packages/96/62/ed93cb8ae7e2ad8c5fe874e8027306aeee0c6a02c04fa015b5f99d14b3db/ruamel.yaml.clib-0.1.2-cp36-cp36m-manylinux1_x86_64.whl (549kB)
#      |████████████████████████████████| 552kB 49.2MB/s
# Building wheels for collected packages: pyquil, antlr4-python3-runtime, rpcq
#   Building wheel for pyquil (setup.py) ... done
#   Created wheel for pyquil: filename=pyquil-2.11.0-cp36-none-any.whl size=199819 sha256=a96ce464384057aa16d4a75ea685c7c180691b2216febc447a4afecbb8dc141b
#   Stored in directory: /root/.cache/pip/wheels/eb/7b/21/bbf57d58f34c48af6aa8dbf6392ac3c3b40b6b55ddf6e5af8d
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.7.2-cp36-none-any.whl size=140952 sha256=28466c14b8435329a3da28bbd2c2135ec75f2ab1812053e0b25a56fee1293f91
#   Stored in directory: /root/.cache/pip/wheels/03/65/47/b6700d23b7529a49513f7601b4f96174a4fa9efdbec03e7ea3
#   Building wheel for rpcq (setup.py) ... done
#   Created wheel for rpcq: filename=rpcq-2.7.3-cp36-none-any.whl size=42293 sha256=399a07f43d552922230b25a765d5481d9cfe3e57e7de84211eb848f0711789fe
#   Stored in directory: /root/.cache/pip/wheels/e6/e3/62/24c8c5cd9d661ae478bcfd0030a8598ba9299ab27391bfed0e
# Successfully built pyquil antlr4-python3-runtime rpcq
# Installing collected packages: antlr4-python3-runtime, msgpack, python-rapidjson, pyzmq, ruamel.yaml.clib, ruamel.yaml, rpcq, immutables, pyquil
#   Found existing installation: pyzmq 16.0.3
#     Uninstalling pyzmq-16.0.3:
#       Successfully uninstalled pyzmq-16.0.3
# Successfully installed antlr4-python3-runtime-4.7.2 immutables-0.6 msgpack-0.6.1 pyquil-2.11.0 python-rapidjson-0.8.0 pyzmq-18.1.0 rpcq-2.7.3 ruamel.yaml-0.16.5 ruamel.yaml.clib-0.1.2
# Cloning into 'pennylane-forest'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 378 (delta 62), reused 45 (delta 36), pack-reused 297
# Receiving objects: 100% (378/378), 2.48 MiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (252/252), done.
# /content/pennylane-forest
# Obtaining file:///content/pennylane-forest
# Requirement already satisfied: pyquil>=2.7 in /usr/local/lib/python3.6/site-packages (from PennyLane-Forest==0.4.0.dev0) (2.11.0)
# Requirement already satisfied: pennylane>=0.4 in /usr/local/lib/python3.6/site-packages (from PennyLane-Forest==0.4.0.dev0) (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (1.11.0)
# Requirement already satisfied: rpcq>=2.7.2 in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (2.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (2.22.0)
# Requirement already satisfied: immutables==0.6 in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.6)
# Requirement already satisfied: networkx>=2.0.0 in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (1.17.2)
# Requirement already satisfied: antlr4-python3-runtime in /usr/local/lib/python3.6/site-packages (from pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (4.7.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.6/site-packages (from pennylane>=0.4->PennyLane-Forest==0.4.0.dev0) (0.10.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.6/site-packages (from pennylane>=0.4->PennyLane-Forest==0.4.0.dev0) (1.4.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/site-packages (from pennylane>=0.4->PennyLane-Forest==0.4.0.dev0) (1.0.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.6/site-packages (from pennylane>=0.4->PennyLane-Forest==0.4.0.dev0) (1.3)
# Requirement already satisfied: semantic-version==2.6 in /usr/local/lib/python3.6/site-packages (from pennylane>=0.4->PennyLane-Forest==0.4.0.dev0) (2.6.0)
# Requirement already satisfied: msgpack>=0.6 in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.6.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.17.1)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (3.6.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (18.1.0)
# Requirement already satisfied: python-rapidjson in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.8.0)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.6/site-packages (from rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.16.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (2.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (2019.6.16)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx>=2.0.0->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (4.4.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" in /usr/local/lib/python3.6/site-packages (from ruamel.yaml->rpcq>=2.7.2->pyquil>=2.7->PennyLane-Forest==0.4.0.dev0) (0.1.2)
# Installing collected packages: PennyLane-Forest
#   Running setup.py develop for PennyLane-Forest
# Successfully installed PennyLane-Forest
# /content
# CPU times: user 257 ms, sys: 207 ms, total: 464 ms
# Wall time: 24.2 s

# %%
# VERIFY THE VERSION DOWNLOADED AND UPDATE THE NUMBER IN THE PATH
# !/content/forest-sdk-2.11.0-linux-deb/forest-sdk-2.11.0-linux-deb.run --quiet --accept
# !pip install --upgrade pyquil
# !git clone https://github.com/rigetti/pennylane-forest
# %cd pennylane-forest
# !pip install -e .
# %cd ..
# Out:
#                       End User License Agreement
#                 Forest(TM) 2.0 Software Development Kit
#
# Thank you for your interest in Rigetti & Co, Inc., a Delaware corporation (commo
# nly referred to as Rigetti Computing) (“Rigetti”), and our Forest(TM) Software D
# evelopment Kit and associated downloadable materials (collectively, “Forest SDK”
# ). Please read this End User License Agreement (“EULA”) carefully, as it constit
# utes a legally binding agreement governing your use of the Forest SDK (as such t
# erms are defined below).
#
# BY CLICKING “I ACCEPT,” OR BY OTHERWISE DOWNLOADING OR USING THE FOREST SDK, YOU
#  AGREE THAT YOU HAVE READ, UNDERSTOOD AND AGREE TO BY BOUND BY THE FOLLOWING TER
# MS AND CONDITIONS. IF YOU DO NOT AGREE, YOU MAY NOT DOWNLOAD, REPRODUCE, INSTALL
# , OR OTHERWISE ACCESS THE FOREST SDK.
#
# If you are using the software on behalf of an entity, such as a company or organ
# ization, you are agreeing to this EULA on behalf of such entity (and you represe
# nt that you have the legal authority to do so), and the words “You,” “Your” and
# "Yourself" in this EULA will refer not only to you as an individual, but also to
#  such entity and any other person using the software on such entity's behalf.
#
# Summaries of certain sections of this EULA have been included to help You unders
# tand them. These summaries are for Your convenience only; they will not affect,
# and they may not be used to interpret, the meaning of this EULA.
#
# 1.      The QCS Service.
# Summary: This EULA grants a license only under the Forest Software Development K
# it, designed for use in conjunction with the Rigetti QCS Service.  The QCS Terms
#  of Service still apply, and must be accepted separately when you sign up for an
#  account.
# a.      QCS Access. In order to run your software on actual quantum hardware, yo
# u must also visit https://www.rigetti.com and sign up for a QCS account, unless
# one has been provided through your organization.
# b.      Order of Precedence. As between this EULA and the QCS Terms of Service,
# this EULA shall govern only use of the Forest SDK.  The Terms of Service shall g
# overn all other aspects of your online account, if applicable, except as amended
#  or supplemented by other agreements.
#
# 2.      Your License to the Forest SDK.
# Summary: Your license to use the Forest SDK is subject to certain restrictions.
# a.      License Grant. Rigetti grants You a non-exclusive, non-sublicenseable, n
# on-assignable, worldwide, terminable license, under its patents and copyrights f
# ully embodied in the Forest SDK to install and run a single instance of the Fore
# st SDK on a single computer.
# b.      Restrictions & Limitations. You acknowledge and agree that the license o
# f Section 2(a) above excludes the right to use the Forest SDK in connection with
#  the design, development, marketing, promotion, sale, support or maintenance of
# any of the following: (i) any third-party quantum processors or other quantum co
# mputing hardware (collectively, "Quantum Hardware"); (ii) any third-party softwa
# re or hardware that virtualizes or otherwise simulates any Quantum Hardware; or
# (iii) any third-party hardware or software (including any tool, library or other
#  computer code) that enables the development of software for, or the execution o
# f software on, any non-Rigetti Quantum Hardware, or otherwise facilitates access
#  to or use of any non-Rigetti Quantum Hardware. You further acknowledge and agre
# e that the licenses of Section 2(a) exclude the right to use the Forest SDK in c
# onjunction with or running on top of any third-party Quantum Hardware or softwar
#  MD5 checksums are OK.

# %% [markdown]
# RESTART THE RUNTIME
#
# Click on "**Runtime > Restart Runtime...**"

# %%
# !quilc --version
# !qvm --version
# !python -c "import pyquil; print(pyquil.__version__)"
# !nohup quilc -S &
# !nohup qvm -S &
# !ps -aux
# Out:
# quilc: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.28' not found (required by quilc)
# qvm: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.28' not found (required by qvm)
# 2.11.0
# nohup: appending output to 'nohup.out'
# nohup: appending output to 'nohup.out'
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root           1  0.0  0.0  39192  6264 ?        Ss   12:36   0:00 /bin/bash -e
# root           8  0.3  0.4 687764 56316 ?        Sl   12:36   0:04 /tools/node/b
# root          25  0.5  0.7 406248 102188 ?       Sl   12:36   0:07 /usr/bin/pyth
# root         116  0.0  0.0  35884  4888 ?        Ss   12:37   0:00 tail -n +0 -F
# root        3106  9.9  1.1 618544 147472 ?       Ssl  12:59   0:01 /usr/bin/pyth
# root        3138  0.0  0.0  54836  6516 ?        R    13:00   0:00 ps -aux

# %%
from pkg_resources import iter_entry_points
print(sum(1 for _ in iter_entry_points("pennylane.plugins")))
for i in iter_entry_points("pennylane.plugins"):
  print(i)
# Out:
# 0

# %%
X_train = pickle.load(open('X_train.pkl','r'))
y_train = pickle.load(open('y_train.pkl','r'))

# %%
import pennylane as qml
from pennylane import numpy as np
import pennylane.optimize
import os
import time
import random
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchsummary import summary
import torchvision.datasets as dset
import torchvision.transforms as transforms

# %%
ENCODING_SIZE = 10
NUM_QUBITS = 10
EPOCHS = 100
dev = qml.device("forest.qvm", device="{}q-pyqvm".format(NUM_QUBITS), shots=1600)
#dev = qml.device('default.qubit', wires=NUM_QUBITS)
from pennylane.ops import RX, RY, CNOT
# x will be a length ENCODING_SIZE vector that represents
# the encoding of a MNIST image
# thetas is of size 2 * NUM_QUBITS
@qml.qnode(dev)
def circuit(x, thetas):
    for i in range(ENCODING_SIZE):
        RX(x[i], wires=i)
    for i in range(NUM_QUBITS - 1):
        CNOT(wires=[i, i+1])
    for i in range(NUM_QUBITS):
        RX(thetas[i], wires=i)
    for i in range(NUM_QUBITS, 2 * NUM_QUBITS):
        RY(thetas[i], wires=(i - NUM_QUBITS))
    return tuple(qml.expval.PauliZ(wires=i) for i in range(NUM_QUBITS))

def cost(X, actual_labels, thetas):
    b = X.shape[0]
    yhats = []
    for i in range(b):
        yhat = circuit(X[i], thetas)
        yhats.append(yhat)
    st = np.stack(yhats)
    actual_class_vals = st[range(b), actual_labels]
    shifted = st - np.max(st, axis=1)[:, np.newaxis]
    the_sum = np.log(np.sum(np.exp(shifted), axis=1))
    return np.mean(-actual_class_vals + the_sum)

def accuracy(thetas, number_batches=3):
    correct = 0
    total = 0
    for i, data in enumerate(X_test):
        if i == number_batches:
            break
        predicted = []
        for record in X_test:
            ys = circuit(record, thetas)
            predicted.append(np.argmax(ys))
        correct += (np.asarray(predicted) == y_test).sum()
        total += len(predicted)
    return(correct / total)

thetas = 2 * np.random.rand(2 * NUM_QUBITS) - 1
print(thetas)
print(thetas.dtype)

#print(circuit(inputs[0].view(1, -1).numpy(), thetas))

print(thetas.shape)
start = time.time()
grad = qml.grad(cost, argnum=2)(X_train, y_train, thetas) 
print(grad)
print(grad.shape)
print(time.time() - start)

eta = .1
start = time.time()
accuracies = []
for epoch in range(1):
    for i in range(EPOCHS):
        grad = qml.grad(cost, argnum=2)(X_train, y_train, thetas)
        thetas -= eta * grad
        acc = accuracy(thetas)
        accuracies.append(acc)
        print("%d batches took %f seconds and has accuracy %f" % (i + 1, time.time() - start, acc))

plt.plot(accuracies)
plt.show()
print(thetas)
